# %%
# Intialization
import os
import sys

os.environ["SPARK_HOME"] = "/home/talentum/spark"
os.environ["PYLIB"] = os.environ["SPARK_HOME"] + "/python/lib"
# In below two lines, use /usr/bin/python2.7 if you want to use Python 2
os.environ["PYSPARK_PYTHON"] = "/usr/bin/python3.6" 
os.environ["PYSPARK_DRIVER_PYTHON"] = "/usr/bin/python3"
sys.path.insert(0, os.environ["PYLIB"] +"/py4j-0.10.7-src.zip")
sys.path.insert(0, os.environ["PYLIB"] +"/pyspark.zip")

# NOTE: Whichever package you want mention here.
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0 pyspark-shell' 
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.3 pyspark-shell'
# os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages com.databricks:spark-xml_2.11:0.6.0,org.apache.spark:spark-avro_2.11:2.4.0 pyspark-shell'

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit
from pyspark.sql.types import StringType
from functools import reduce

# %%
import pandas as pd
import glob

# %%
#Entrypoint 2.x
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("CSV Merger").enableHiveSupport().getOrCreate()



# On yarn:
# spark = SparkSession.builder.appName("Spark SQL basic example").enableHiveSupport().master("yarn").getOrCreate()
# specify .master("yarn")

sc = spark.sparkContext

# %%
def create_dict_from_csv(file_path):
    df = pd.read_csv(file_path)
    df['file_name'] = df['file_name'].str[:2]
    result_dict = pd.Series(df['file_name'].values, index=df['state']).to_dict()
    return result_dict

# Example usage
file_path = r'/home/talentum/myproject/dataSource/stations_info.csv'
state_dict = create_dict_from_csv(file_path)
print(state_dict)
# Out:
# {'Andhra Pradesh': 'AP', 'Arunachal Pradesh': 'AR', 'Assam': 'AS', 'Bihar': 'BR', 'Chhattisgarh': 'CG', 'Chandigarh': 'CH', 'Delhi': 'DL', 'Gujarat': 'GJ', 'Himachal Pradesh': 'HP', 'Haryana': 'HR', 'Jharkhand': 'JH', 'Jammu and Kashmir': 'JK', 'Karnataka': 'KA', 'Kerala': 'KL', 'Maharashtra': 'MH', 'Meghalaya': 'ML', 'Manipur': 'MN', 'Madhya Pradesh': 'MP', 'Mizoram': 'MZ', 'Nagaland': 'NL', 'Odisha': 'OR', 'Punjab': 'PB', 'Puducherry': 'PY', 'Rajasthan': 'RJ', 'Sikkim': 'SK', 'Telangana': 'TG', 'Tamil Nadu': 'TN', 'Tripura': 'TR', 'Uttarakhand': 'UK', 'Uttar Pradesh': 'UP', 'West Bengal': 'WB'}

# %%
print(list(state_dict.values()))
# Out:
# ['AP', 'AR', 'AS', 'BR', 'CG', 'CH', 'DL', 'GJ', 'HP', 'HR', 'JH', 'JK', 'KA', 'KL', 'MH', 'ML', 'MN', 'MP', 'MZ', 'NL', 'OR', 'PB', 'PY', 'RJ', 'SK', 'TG', 'TN', 'TR', 'UK', 'UP', 'WB']

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit
from pyspark.sql.types import StringType
import os

# Initialize Spark session
spark = SparkSession.builder.appName("CSVProcessor").getOrCreate()

# Define the directory paths
directory_path = 'file:////home/talentum/myproject/dataSource/archive'
savepath = 'file:////home/talentum/myproject/dataSource/output'

# Define the prefixes you want to handle (assuming state_dict is defined elsewhere)
prefixes = list(state_dict.values())  # Add other prefixes as needed

# Function to normalize column names
def normalize_column_names(df):
    normalized_columns = [col.strip().replace(' ', '_').replace('.', '_').replace('(', '').replace(')', '') for col in df.columns]
    return df.toDF(*normalized_columns)

# Function to ensure correct data types
def ensure_data_types(df, columns):
    for column in columns:
        if column not in df.columns:
            df = df.withColumn(column, lit(None).cast(StringType()))
    return df.select(columns)

# Process each prefix
for prefix in prefixes:
    # Define the search pattern
    search_pattern = os.path.join(directory_path, f'{prefix}*.csv')
    
    # Read all CSV files using Spark's read method
    df = spark.read.option("header", "true").csv(search_pattern, inferSchema=True)
    
    if df.count() > 0:
        # Normalize column names
        df = normalize_column_names(df)
        
        # Identify all columns in the DataFrame
        all_columns = sorted(df.columns)  # Sort columns for consistency
        
        # Ensure DataFrame has the correct columns and data types
        df = ensure_data_types(df, all_columns)
        
        # Extract state abbreviation from file names (assuming prefix is the state abbreviation)
        state_abbr = prefix
        state_name = next((name for name, abbr in state_dict.items() if abbr == state_abbr), None)
        
        # Add the state column
        df = df.withColumn('state', lit(state_name).cast(StringType()))
        
        # Save the DataFrame to a single CSV file
        output_path = os.path.join(savepath, f'{prefix}')
        df.coalesce(1).write.option("header", "true").csv(output_path, mode='overwrite')
        print(f"Merged CSV files for prefix '{prefix}' saved as part csv file inside {prefix} folder'")
    else:
        print(f"No valid files found for prefix '{prefix}'.")

# Stop the Spark session
spark.stop()
# Out:
# Merged CSV files for prefix 'AP' saved as 'merged_output_AP.csv'
# Merged CSV files for prefix 'AR' saved as 'merged_output_AR.csv'
# Merged CSV files for prefix 'AS' saved as 'merged_output_AS.csv'
# Merged CSV files for prefix 'BR' saved as 'merged_output_BR.csv'
# Merged CSV files for prefix 'CG' saved as 'merged_output_CG.csv'
# Merged CSV files for prefix 'CH' saved as 'merged_output_CH.csv'
# Merged CSV files for prefix 'DL' saved as 'merged_output_DL.csv'
# Merged CSV files for prefix 'GJ' saved as 'merged_output_GJ.csv'
# Merged CSV files for prefix 'HP' saved as 'merged_output_HP.csv'
# Merged CSV files for prefix 'HR' saved as 'merged_output_HR.csv'
# Merged CSV files for prefix 'JH' saved as 'merged_output_JH.csv'
# Merged CSV files for prefix 'JK' saved as 'merged_output_JK.csv'
# Merged CSV files for prefix 'KA' saved as 'merged_output_KA.csv'
# Merged CSV files for prefix 'KL' saved as 'merged_output_KL.csv'
# Merged CSV files for prefix 'MH' saved as 'merged_output_MH.csv'
# Merged CSV files for prefix 'ML' saved as 'merged_output_ML.csv'
# Merged CSV files for prefix 'MN' saved as 'merged_output_MN.csv'
# Merged CSV files for prefix 'MP' saved as 'merged_output_MP.csv'
# Merged CSV files for prefix 'MZ' saved as 'merged_output_MZ.csv'
# Merged CSV files for prefix 'NL' saved as 'merged_output_NL.csv'
# Merged CSV files for prefix 'OR' saved as 'merged_output_OR.csv'
# Merged CSV files for prefix 'PB' saved as 'merged_output_PB.csv'
# Merged CSV files for prefix 'PY' saved as 'merged_output_PY.csv'
# Merged CSV files for prefix 'RJ' saved as 'merged_output_RJ.csv'
# Merged CSV files for prefix 'SK' saved as 'merged_output_SK.csv'
# Merged CSV files for prefix 'TG' saved as 'merged_output_TG.csv'
# Merged CSV files for prefix 'TN' saved as 'merged_output_TN.csv'
# Merged CSV files for prefix 'TR' saved as 'merged_output_TR.csv'
# Merged CSV files for prefix 'UK' saved as 'merged_output_UK.csv'
# Merged CSV files for prefix 'UP' saved as 'merged_output_UP.csv'
# Merged CSV files for prefix 'WB' saved as 'merged_output_WB.csv'

# %% [markdown]
# ### data cleaning(state wise)

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit, when, mean as _mean, to_date, count, isnull
from pyspark.sql.types import DoubleType
import os

# Initialize Spark session
spark = SparkSession.builder.appName("DataCleaning").getOrCreate()

def handle_outliers(df, column):
    """Handle outliers in a specific column using the IQR method."""
    Q1 = df.approxQuantile(column, [0.25], 0.01)[0]
    Q3 = df.approxQuantile(column, [0.75], 0.01)[0]
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    df = df.withColumn(column, when((col(column) < lower_bound) | (col(column) > upper_bound), None).otherwise(col(column)))
    median_value = df.approxQuantile(column, [0.5], 0.01)[0]
    df = df.fillna({column: median_value})
    return df

def process_csv_file(file_path, output_dir, state_code):
    """Read, clean, and save a single CSV file."""
    # Read the CSV file into a DataFrame
    df = spark.read.option("header", "true").csv(file_path, inferSchema=True)
    
    total_columns = len(df.columns)
    missing_threshold_row = total_columns * 0.85
    df = df.withColumn('missing_count', sum([isnull(col(c)).cast('int') for c in df.columns]))
    df = df.filter(col('missing_count') <= missing_threshold_row).drop('missing_count')

    # Step 2: Drop columns with more than 50% missing values (based on the new row count)
    total_rows = df.count()
    missing_threshold_col = total_rows * 0.60
    missing_value_counts = {c: df.filter(isnull(col(c))).count() for c in df.columns}
    cols_to_drop = [c for c in missing_value_counts if missing_value_counts[c] > missing_threshold_col]
    df = df.drop(*cols_to_drop)
    
    # Handle outliers and impute missing values for numeric columns
    numeric_columns = [f.name for f in df.schema.fields if isinstance(f.dataType, DoubleType)]
    for column in numeric_columns:
        df = handle_outliers(df, column)
    
    # Remove duplicates
    df = df.dropDuplicates()
    
    # Convert date columns
    if 'From Date' in df.columns and 'To Date' in df.columns:
        df = df.withColumn('From_Date', to_date(col('From Date'), 'yyyy-MM-dd'))
        df = df.withColumn('To_Date', to_date(col('To Date'), 'yyyy-MM-dd'))
        df = df.drop('From Date', 'To Date')
    
    # Normalize column names
    normalized_columns = [col.strip().replace(' ', '_').replace('.', '_').replace('(', '').replace(')', '').lower() for col in df.columns]
    df = df.toDF(*normalized_columns)
    
    # Show the DataFrame and print remaining columns
    df.show()
    print(f"Columns after cleaning: {df.columns}")
    
    # Print a red warning if the number of columns is less than 12
    if len(df.columns) < 12:
        print("\033[91mWarning: The number of columns after cleaning is less than 10.\033[0m")
    
    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    # Save the cleaned DataFrame to a single CSV file
    output_file = os.path.join(output_dir, f'{state_code}')
    df.coalesce(1).write.option("header", "true").csv(f'file://{output_file}', mode='overwrite')
    print(f'Cleaned data saved to {output_file}')

def process_all_files(state_codes, base_path, output_dir):
    """Process CSV files from multiple state codes."""
    for state_code in state_codes:
        file_path = os.path.join(base_path, state_code, '*.csv')
        process_csv_file(file_path, output_dir, state_code)

# Define state codes, base path, and output directory
state_codes = list(state_dict.values())  # Example state codes
# state_codes = ['JH']
base_path = 'file:///home/talentum/myproject/dataSource/output'
output_dir = '/home/talentum/myproject/dataSource/output/Cleaned'

# Process all files
process_all_files(state_codes, base_path, output_dir)

# Stop the Spark session
spark.stop()
# base_cleaned_file_path='hdfs:///user/talentum/output'
# Out:
# +-----------+-------+-------------+--------+----------------+---------+---------+--------+-------+-----------+----------+-----------+-----+-----+---------+--------+-------------+----------------+-------------+-------+------+------+------------+--------------+
# |at_degree_c|bp_mmhg|benzene_ug/m3|co_mg/m3|       from_date|nh3_ug/m3|no2_ug/m3|no_ug/m3|nox_ppb|ozone_ug/m3|pm10_ug/m3|pm2_5_ug/m3|rf_mm| rh_%|so2_ug/m3|sr_w/mt2|temp_degree_c|         to_date|toluene_ug/m3|vws_m/s|wd_deg|ws_m/s|xylene_ug/m3|         state|
# +-----------+-------+-------------+--------+----------------+---------+---------+--------+-------+-----------+----------+-----------+-----+-----+---------+--------+-------
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, mean as _mean, isnull
from pyspark.sql.types import DoubleType, IntegerType

# Initialize Spark session
spark = SparkSession.builder \
    .appName("CSVProcessing") \
    .getOrCreate()

def process_csv_files_from_path(path_pattern):
    """Process all CSV files matching a path pattern."""
    try:
        # Load all CSV files into a DataFrame using the path pattern
        df = spark.read.option("header", "true").csv(path_pattern, inferSchema=True)
        
        # Calculate the mean of each numeric column
        numeric_columns = [field.name for field in df.schema.fields if isinstance(field.dataType, (DoubleType, IntegerType))]
        mean_values = df.select([_mean(col(column)).alias(column) for column in numeric_columns]).collect()[0].asDict()
        
        # Calculate the number of null values per column
        null_counts = {column: df.filter(isnull(col(column))).count() for column in df.columns}
        
        # Total number of rows and columns
        total_rows = df.count()
        total_columns = len(df.columns)

        # Print the results
        print(f"Processing files matching: {path_pattern}")
        print(f"Total Rows: {total_rows}")
        print(f"Total Columns: {total_columns}")
        print("Mean of each feature column:")
        print(mean_values)
        print("Number of null values per column:")
        print(null_counts)
        print()  # Blank line for better readability
    except Exception as e:
        print(f"An error occurred while processing files with pattern {path_pattern}: {e}")

def process_files_for_state_code(state_code, base_paths):
    """Process all CSV files for a single state code across multiple base paths."""
    for base_path in base_paths: 
        print("******************************************************************************************")
        print(f"Processing base path: {base_path} for state code: {state_code}")
        directory = os.path.join(base_path, state_code)
        path_pattern = os.path.join(directory, '*.csv')  # Use wildcard to match all CSV files in the directory
        process_csv_files_from_path(path_pattern)

# Define base paths for directories
base_paths = [
    'file:///home/talentum/myproject/dataSource/output',
    'file:///home/talentum/myproject/dataSource/output/Cleaned'
]

# Example state codes
state_codes = list(state_dict.values())

# Process all files for each state code across all base paths
for state_code in state_codes:
    process_files_for_state_code(state_code, base_paths)

# Stop the Spark session
spark.stop()
# Out:
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: AP
# Processing files matching: file:///home/talentum/myproject/dataSource/output/AP/*.csv
# Total Rows: 272217
# Total Columns: 24
# Mean of each feature column:
# {'AT_degree_C': 19.804636198831712, 'BP_mmHg': 329.26510965319864, 'Benzene_ug/m3': 1.3425025154651606, 'CO_mg/m3': 0.6732711137891778, 'NH3_ug/m3': 11.814804842056729, 'NO2_ug/m3': 26.583451043266106, 'NO_ug/m3': 8.807595412416097, 'NOx_ppb': 21.877951389045055, 'Ozone_ug/m3': 33.42829703974618, 'PM10_ug/m3': 75.24238959315365, 'PM2_5_ug/m3': 36.22938336606634, 'RF_mm': 0.39835663419207146, 'RH_%': 36.018222775945446, 'SO2_ug/m3': 9.714749217093633, 'SR_W/mt2': 46.66403755271794, 'Temp_degree_C': 21.804508160189453, 'Toluene_ug/m3': 4.2030759198924175, 'VWS_m/s': 75.46110700906699, 'WD_deg': 124.91501163174138, 'WS_m/s': 10.932443972660211, 'Xylene_ug/m3': 418.8148581571445}
# Number of null values per column:
 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: AR
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/AR/*.csv
# Total Rows: 8131
# Total Columns: 22
# Mean of each feature column:
# {'at_degree_c': 24.47912679867176, 'bp_mmhg': 986.694181527488, 'benzene_ug/m3': 0.017455417537818464, 'co_mg/m3': 0.3154974787848973, 'eth-benzene_ug/m3': 0.07443364899766473, 'mp-xylene_ug/m3': 0.09005534374616114, 'nh3_ug/m3': 2.1917267248800454, 'no2_ug/m3': 6.342155946377884, 'no_ug/m3': 1.866321485672188, 'nox_ppb': 7.3799446562538495, 'ozone_ug/m3': 8.526028778747998, 'pm10_ug/m3': 43.67319394908417, 'pm2_5_ug/m3': 19.033717869880675, 'rf_mm': 0.0, 'rh_%': 77.08656007871129, 'so2_ug/m3': 24.133294797686823, 'sr_w/mt2': 130.35683556757618, 'wd_degree': 173.89019554790272, 'ws_m/s': 0.43401918583200466}
# Number of null values per column:
# {'at_degree_c': 0, 'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'eth-benzene_ug/m3': 0, 'from_date': 0, 'mp-xylene_ug/m3': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rf_mm': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'to_date': 0, 'wd_degree': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: AS
# Processing files matching: file:///home/talentum/myproject/dataSource/output/AS/*.csv
# Total Rows: 75171
# Total Columns: 24
# Mean of each feature column:
# {'AT_degree_C': 23.08275491766243, 'BP_mmHg': 773.9045565791284, 'Benzene_ug/m3': 0.9699783667621561, 'CO_mg/m3': 0.7797538744526322, 'Eth-Benzene_ug/m3': 2.435919825300256, 'MP-Xylene_ug/m3': 2.1241766236390305, 'NH3_ug/m3': 11.122639749810677, 'NO2_ug/m3': 10.430961027207436, 'NO_ug/m3': 9.889399408657159, 'NOx_ppb': 17.410681169366036, 'O_Xylene_ug/m3': 53.20560355930208, 'Ozone_ug/m3': 22.688810000710244, 'PM10_ug/m3': 129.1494179020941, 'PM2_5_ug/m3': 69.1129790774395, 'RF_mm': 0.06818384349399946, 'RH_%': 61.38720094966744, 'SO2_ug/m3': 19.282342854770384, 'SR_W/mt2': 163.36297114692434, 'Toluene_ug/m3': 2.906608536025688, 'WD_degree': 135.8352714526001, 'WS_m/s': 19.829321517272525}
# Number of null values per column:
# {'AT_degree_C': 26469, 'BP_mmHg': 38806, 'Benzene_ug/m3': 5371, 'CO_mg/m3': 2322, 'Eth-Benzene_ug/m3': 43116, 'From_Date': 0, 'MP-Xylene_ug/m3': 35584, 'NH3_ug/m3': 3865, 'NO2_ug/m3': 4455, 'NO_ug/m3': 3808, 'NOx_ppb': 2311, 'O_Xylene_ug/m3': 66630, 'Ozone_ug/m3': 4776, 'PM10_ug/m3': 5492, 'PM2_5_ug/m3': 6059, 'RF_mm': 32080, 'RH_%': 22521, 'SO2_ug/m3': 2913, 'SR_W/mt2': 21000, 'To_Date': 0, 'Toluene_ug/m3': 68634, 'WD_degree': 4422, 'WS_m/s': 4307, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: AS
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/AS/*.csv
# Total Rows: 73172
# Total Columns: 22
# Mean of each feature column:
# {'at_degree_c': 23.66648444759784, 'bp_mmhg': 972.85479063038, 'benzene_ug/m3': 0.29572801071448407, 'co_mg/m3': 0.5922231181326041, 'eth-benzene_ug/m3': 0.5020540643963151, 'mp-xylene_ug/m3': 0.4831710217023317, 'nh3_ug/m3': 9.329649046082944, 'no2_ug/m3': 7.331823238397009, 'no_ug/m3': 2.973990050839379, 'nox_ppb': 8.199863335701737, 'ozone_ug/m3': 16.57187435084539, 'pm10_ug/m3': 101.63509525501621, 'pm2_5_ug/m3': 54.818719045536845, 'rf_mm': 0.0, 'rh_%': 64.40295755206182, 'so2_ug/m3': 16.162197015251486, 'sr_w/mt2': 119.75098630623722, 'wd_degree': 126.79296534193442, 'ws_m/s': 1.0232856830482342}
# Number of null values per column:
# {'at_degree_c': 0, 'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'eth-benzene_ug/m3': 0, 'from_date': 0, 'mp-xylene_ug/m3': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rf_mm': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'to_date': 0, 'wd_degree': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: BR
# Processing files matching: file:///home/talentum/myproject/dataSource/output/BR/*.csv
# Total Rows: 741917
# Total Columns: 21
# Mean of each feature column:
# {'AT_degree_C': 296.5915512829498, 'BP_mmHg': 162.29743212421798, 'Benzene_ug/m3': 1.2740040265472965, 'CO_mg/m3': 16.650435141109153, 'NO2_ug/m3': 17.24798392445838, 'NO_ug/m3': 135.31558805426553, 'NOx_ppb': 33.846674045857434, 'Ozone_ug/m3': 15.69878764977306, 'PM2_5_ug/m3': 93.54976793994643, 'RH_%': 17.54011786138579, 'SO2_ug/m3': 24.189772064147963, 'SR_W/mt2': 178.88260657841653, 'Temp_': 11.429118304050053, 'Toluene_ug/m3': 27.169655309306012, 'VWS_m/s': 66.44703430014343, 'WD_deg': 48.77093875213774, 'WS_m/s': 10.263150931166903, 'Xylene_ug/m3': 124.20495518300474}
# Number of null values per column:
# {'AT_degree_C': 151077, 'BP_mmHg': 126159, 'Benzene_ug/m3': 197530, 'CO_mg/m3': 175549, 'From_Date': 0, 'NO2_ug/m3': 141875, 'NO_ug/m3': 152150, 'NOx_ppb': 140225, 'Ozone_ug/m3': 151774, 'PM2_5_ug/m3': 167626, 'RH_%': 147999, 'SO2_ug/m3': 132886, 'SR_W/mt2': 356262, 'Temp_': 158598, 'To_Date': 0, 'Toluene_ug/m3': 160033, 'VWS_m/s': 126322, 'WD_deg': 184869, 'WS_m/s': 177249, 'Xylene_ug/m3': 143818, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: BR
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/BR/*.csv
# Total Rows: 636501
# Total Columns: 21
# Mean of each feature column:
# {'at_degree_c': 279.49396608958887, 'bp_mmhg': 24.236831442536275, 'benzene_ug/m3': 0.8456347594111059, 'co_mg/m3': 12.51077795635839, 'no2_ug/m3': 7.1262072486912995, 'no_ug/m3': 118.51778262723448, 'nox_ppb': 26.4241382338695, 'ozone_ug/m3': 7.826433234196017, 'pm2_5_ug/m3': 77.58462937210412, 'rh_%': 2.9713085603968468, 'so2_ug/m3': 16.804443512262875, 'sr_w/mt2': 66.28437330031579, 'temp_': 6.879207636751628, 'toluene_ug/m3': 21.19503592294964, 'vws_m/s': 38.45657907844939, 'wd_deg': 7.125869008838849, 'ws_m/s': 0.8928310717502351, 'xylene_ug/m3': 99.39875499019521}
# Number of null values per column:
# {'at_degree_c': 0, 'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'from_date': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'temp_': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'vws_m/s': 0, 'wd_deg': 0, 'ws_m/s': 0, 'xylene_ug/m3': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: CG
# Processing files matching: file:///home/talentum/myproject/dataSource/output/CG/*.csv
# Total Rows: 62952
# Total Columns: 17
# Mean of each feature column:
# {'AT_degree_C': 115.98050656247399, 'BP_mmHg': 273.4766754500309, 'CO_mg/m3': 9.95658470218185, 'NO2_ug/m3': 29.139502749712044, 'NO_ug/m3': 14.262759012994932, 'NOx_ppb': 30.76111845091019, 'PM10_ug/m3': 79.77180425136743, 'PM2_5_ug/m3': 31.99887044835275, 'RF_mm': 100.24664889944515, 'RH_%': 18.043609501460868, 'SO2_ug/m3': 18.348453848295343, 'SR_W/mt2': 84.27078933554337, 'WD_degree': 59.50426515958925, 'WS_m/s': 14.63343930715808}
# Number of null values per column:
# {'AT_degree_C': 26609, 'BP_mmHg': 26899, 'CO_mg/m3': 22894, 'From_Date': 0, 'NO2_ug/m3': 23857, 'NO_ug/m3': 23398, 'NOx_ppb': 23290, 'PM10_ug/m3': 24188, 'PM2_5_ug/m3': 22582, 'RF_mm': 26743, 'RH_%': 21190, 'SO2_ug/m3': 23441, 'SR_W/mt2': 26757, 'To_Date': 0, 'WD_degree': 27298, 'WS_m/s': 26811, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: CG
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/CG/*.csv
# Total Rows: 49048
# Total Columns: 17
# Mean of each feature column:
# {'at_degree_c': 108.83109301091174, 'bp_mmhg': 201.2536735442608, 'co_mg/m3': 6.666632686347467, 'no2_ug/m3': 23.60573213994371, 'no_ug/m3': 7.053020714402186, 'nox_ppb': 22.74899547382143, 'pm10_ug/m3': 67.18483607894547, 'pm2_5_ug/m3': 27.539052764639095, 'rf_mm': 13.285864867069549, 'rh_%': 8.010690751917485, 'so2_ug/m3': 13.972411719131943, 'sr_w/mt2': 43.87812530581987, 'wd_degree': 14.643803009300242, 'ws_m/s': 5.334268267819414}
# Number of null values per column:
# {'at_degree_c': 0, 'bp_mmhg': 0, 'co_mg/m3': 0, 'from_date': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rf_mm': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'to_date': 0, 'wd_degree': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: CH
# Processing files matching: file:///home/talentum/myproject/dataSource/output/CH/*.csv
# Total Rows: 56647
# Total Columns: 25
# Mean of each feature column:
# {'AT_degree_C': 17.935144466388692, 'BP_mmHg': 50.83060525753366, 'Benzene_ug/m3': 3.530110925616774, 'CO_mg/m3': 0.8390488685425076, 'Eth-Benzene_ug/m3': 3.310991252559105, 'MP-Xylene_ug/m3': 4.37887491628841, 'NH3_ug/m3': 40.559822298325976, 'NO2_ug/m3': 29.56318960762328, 'NO_ug/m3': 13.536900120521087, 'NOx_ppb': 26.2762159412098, 'Ozone_ug/m3': 35.43370817395191, 'PM10_ug/m3': 106.93691730858477, 'PM2_5_ug/m3': 53.24052769158438, 'RF_mm': 0.011204784688995224, 'RH_%': 77.52707804224632, 'SO2_ug/m3': 9.5703051752797, 'SR_W/mt2': 193.19597118482716, 'Toluene_ug/m3': 3.380433959813708, 'VWS_m/s': 6.2656479407203385, 'WD_degree': 110.32481193516479, 'WS_m/s': 22.010039999248825, 'Xylene_ug/m3': 7.631499417540399}
# Number of null values per column:
# {'AT_degree_C': 1963, 'BP_mmHg': 33252, 'Benzene_ug/m3': 2737, 'CO_mg/m3': 2911, 'Eth-Benzene_ug/m3': 2917, 'From_Date': 0, 'MP-Xylene_ug/m3': 2891, 'NH3_ug/m3': 4087, 'NO2_ug/m3': 4070, 'NO_ug/m3': 4374, 'NOx_ppb': 3577, 'Ozone_ug/m3': 2793, 'PM10_ug/m3': 2772, 'PM2_5_ug/m3': 3472, 'RF_mm': 25297, 'RH_%': 25305, 'SO2_ug/m3': 3104, 'SR_W/mt2': 2023, 'To_Date': 0, 'Toluene_ug/m3': 2748, 'VWS_m/s': 33435, 'WD_degree': 1985, 'WS_m/s': 3396, 'Xylene_ug/m3': 2566, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: CH
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/CH/*.csv
# Total Rows: 54786
# Total Columns: 25
# Mean of each feature column:
# {'at_degree_c': 17.938690906435884, 'bp_mmhg': 22.438171978242615, 'benzene_ug/m3': 3.0359323549812096, 'co_mg/m3': 0.7444929361515741, 'eth-benzene_ug/m3': 1.9986180776110987, 'mp-xylene_ug/m3': 1.964351476654556, 'nh3_ug/m3': 33.07924250720949, 'no2_ug/m3': 24.242152557222155, 'no_ug/m3': 4.14362209323539, 'nox_ppb': 16.82854780418303, 'ozone_ug/m3': 28.498069579819518, 'pm10_ug/m3': 100.05745938743475, 'pm2_5_ug/m3': 46.65696583068501, 'rf_mm': 0.0, 'rh_%': 83.18542474354942, 'so2_ug/m3': 7.7012674770927925, 'sr_w/mt2': 158.9172056729823, 'toluene_ug/m3': 1.834577994378097, 'vws_m/s': 3.391786222757274, 'wd_degree': 110.2492050888921, 'ws_m/s': 21.43090461066722, 'xylene_ug/m3': 4.218954477421194}
# Number of null values per column:
# {'at_degree_c': 0, 'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'eth-benzene_ug/m3': 0, 'from_date': 0, 'mp-xylene_ug/m3': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rf_mm': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'vws_m/s': 0, 'wd_degree': 0, 'ws_m/s': 0, 'xylene_ug/m3': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: DL
# Processing files matching: file:///home/talentum/myproject/dataSource/output/DL/*.csv
# Total Rows: 2796171
# Total Columns: 26
# Mean of each feature column:
# {'AT_degree_C': 19.02320361698699, 'BP_mmHg': 194.2283388122881, 'Benzene_ug/m3': 4.413258865973651, 'CO_mg/m3': 3.014608674091175, 'Eth-Benzene_ug/m3': 7.813949778657039, 'MP-Xylene_ug/m3': 52.80368179227267, 'NH3_ug/m3': 35.50000248257262, 'NO2_ug/m3': 42.417450547366904, 'NO_ug/m3': 33.831450125784734, 'NOx_ppb': 56.68242362495321, 'O_Xylene_ug/m3': 10.454002353424645, 'Ozone_ug/m3': 29.23767214624395, 'PM10_ug/m3': 212.58201708016188, 'PM2_5_ug/m3': 108.99946115196582, 'RH_%': 102.46317295265811, 'SO2_ug/m3': 14.547854026831995, 'SR_W/mt2': 140.78417659019465, 'Temp_degree_C': 152.29413625963485, 'Toluene_ug/m3': 26.537274938124565, 'VWS_m/s': 95.8873599133961, 'WD_deg': 106.92024020717493, 'WS_m/s': 628.9273513418525, 'Xylene_ug/m3': 8.778021238694881}
# Number of null values per column:
# {'AT_degree_C': 2759013, 'BP_mmHg': 1783498, 'Benzene_ug/m3': 1393364, 'CO_mg/m3': 1074077, 'Eth-Benzene_ug/m3': 2504542, 'From_Date': 0, 'MP-Xylene_ug/m3': 1545378, 'NH3_ug/m3': 1043957, 'NO2_ug/m3': 782527, 'NO_ug/m3': 852381, 'NOx_ppb': 833619, 'O_Xylene_ug/m3': 1454298, 'Ozone_ug/m3': 1032714, 'PM10_ug/m3': 1126515, 'PM2_5_ug/m3': 908997, 'RH_%': 1188413, 'SO2_ug/m3': 800955, 'SR_W/mt2': 1348095, 'Temp_degree_C': 1223673, 'To_Date': 0, 'Toluene_ug/m3': 1472535, 'VWS_m/s': 2329656, 'WD_deg': 1672183, 'WS_m/s': 1203995, 'Xylene_ug/m3': 2592392, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: DL
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/DL/*.csv
# Total Rows: 2118037
# Total Columns: 22
# Mean of each feature column:
# {'bp_mmhg': 0.9034587781044475, 'benzene_ug/m3': 2.3879747001578053, 'co_mg/m3': 1.0788811385219117, 'mp-xylene_ug/m3': 51.657980691755476, 'nh3_ug/m3': 30.44629462098454, 'no2_ug/m3': 34.899530848588114, 'no_ug/m3': 13.162492472964841, 'nox_ppb': 35.697989690430724, 'o_xylene_ug/m3': 1.1179863335647515, 'ozone_ug/m3': 19.171224265675683, 'pm10_ug/m3': 190.135813330929, 'pm2_5_ug/m3': 88.48912179532249, 'rh_%': 31.34809537312035, 'so2_ug/m3': 11.585878716937296, 'sr_w/mt2': 18.45330020210981, 'temp_degree_c': 122.84319892900871, 'toluene_ug/m3': 15.10460339451781, 'wd_deg': 65.04538783821137, 'ws_m/s': 715.0060501502834}
# Number of null values per column:
# {'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'from_date': 0, 'mp-xylene_ug/m3': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'o_xylene_ug/m3': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'temp_degree_c': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'wd_deg': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: GJ
# Processing files matching: file:///home/talentum/myproject/dataSource/output/GJ/*.csv
# Total Rows: 442880
# Total Columns: 25
# Mean of each feature column:
# {'AT_degree_C': 18.68537397443237, 'BP_mmHg': 373.6975973043959, 'Benzene_ug/m3': 16.52145081919679, 'CO_mg/m3': 12.001041174353869, 'Eth-Benzene_ug/m3': 33.032469888926215, 'MP-Xylene_ug/m3': 23.36629624979079, 'NO2_ug/m3': 28.826662823982826, 'NO_ug/m3': 15.330018373831486, 'NOx_ppb': 33.310026528016245, 'O_Xylene_ug/m3': 2.735294686252204, 'Ozone_ug/m3': 8.88429192819121, 'PM10_ug/m3': 109.84167353573547, 'PM2_5_ug/m3': 56.68486987625845, 'RH_%': 42.04448515499744, 'SO2_ug/m3': 25.043650287212536, 'SR_W/mt2': 174.69094969056047, 'Toluene_ug/m3': 10.374569557708973, 'VWS_m/s': 5.222865446006097, 'WD_deg': 94.55447218399593, 'WS_m/s': 25.752284319166858, 'Xylene_ug/m3': 1.7073437298835539}
# Number of null values per column:
# {'AT_degree_C': 243722, 'BP_mmHg': 280246, 'Benzene_ug/m3': 133186, 'CO_mg/m3': 109420, 'Eth-Benzene_ug/m3': 302068, 'From_Date': 0, 'MP-Xylene_ug/m3': 275636, 'NO2_ug/m3': 135803, 'NO_ug/m3': 149528, 'NOx_ppb': 141689, 'O_Xylene_ug/m3': 332186, 'Ozone_ug/m3': 128378, 'PM10_ug/m3': 156815, 'PM2_5_ug/m3': 126412, 'RF_mm': 442880, 'RH_%': 248909, 'SO2_ug/m3': 130395, 'SR_W/mt2': 175793, 'To_Date': 0, 'Toluene_ug/m3': 184634, 'VWS_m/s': 306615, 'WD_deg': 132573, 'WS_m/s': 131181, 'Xylene_ug/m3': 264231, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: GJ
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/GJ/*.csv
# Total Rows: 346017
# Total Columns: 22
# Mean of each feature column:
# Number of null values per column:
# {'AT_': 52638, 'BP_mmHg': 41316, 'Benzene_ug/m3': 47408, 'CO_mg/m3': 32257, 'From_Date': 0, 'NH3_ug/m3': 29898, 'NO2_ug/m3': 28383, 'NO_ug/m3': 28279, 'Ozone_ug/m3': 26618, 'PM10_ug/m3': 26578, 'PM2_5_ug/m3': 43873, 'RH_%': 34326, 'SO2_ug/m3': 28891, 'SR_W/mt2': 33062, 'Temp_degree_C': 29207, 'To_Date': 0, 'VWS_m/s': 28201, 'WD_deg': 50742, 'WS_m/s': 50743, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: JH
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/JH/*.csv
# Total Rows: 52624
# Total Columns: 11
# Mean of each feature column:
# {'nh3_ug/m3': 6.488144952873914, 'no2_ug/m3': 9.058388948008472, 'no_ug/m3': 7.848810048643914, 'ozone_ug/m3': 23.251958612033935, 'pm10_ug/m3': 110.30104648071666, 'so2_ug/m3': 16.930618919121383, 'temp_degree_c': 25.447726512612412, 'vws_m/s': -2.5547356719374577}
# Number of null values per column:
# {'from_date': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'so2_ug/m3': 0, 'temp_degree_c': 0, 'to_date': 0, 'vws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: JK
# Processing files matching: file:///home/talentum/myproject/dataSource/output/JK/*.csv
# Total Rows: 18733
# Total Columns: 24
# Mean of each feature column:
# {'Benzene_ug/m3': 4.900091563113182, 'CO_mg/m3': 0.3523172119487795, 'Eth-Benzene_ug/m3': 38.8501913875599, 'NH3_ug/m3': 45.59971451809649, 'NO2_ug/m3': 14.668249206349163, 'NO_ug/m3': 9.298381398406036, 'NOx_ppb': 18.488745755204448, 'Ozone_ug/m3': 8.657756038321418, 'PM10_ug/m3': 84.16598791201903, 'PM2_5_ug/m3': 28.526610391228733, 'RF_mm': 0.013119698960697607, 'RH_%': 70.87994698605907, 'SO2_ug/m3': 12.916581839640017, 'SR_W/mt2': 184.51164068960966, 'Temp_degree_C': 14.735590359722545, 'Toluene_ug/m3': 3.484827046077438, 'WD_degree': 170.25106795530047, 'WS_m/s': 0.3591285930408441, 'Xylene_ug/m3': 60.039793103448254}
# Number of null values per column:
# {'Benzene_ug/m3': 17204, 'CO_mg/m3': 4673, 'Eth-Benzene_ug/m3': 18106, 'From_Date': 0, 'MP-Xylene_ug/m3': 18733, 'NH3_ug/m3': 6438, 'NO2_ug/m3': 6133, 'NO_ug/m3': 6562, 'NOx_ppb': 5187, 'O_Xylene_ug/m3': 18733, 'Ozone_ug/m3': 3911, 'PM10_ug/m3': 2684, 'PM2_5_ug/m3': 2681, 'RF_mm': 1991, 'RH_%': 3454, 'SO2_ug/m3': 5176, 'SR_W/mt2': 3014, 'Temp_degree_C': 4750, 'To_Date': 0, 'Toluene_ug/m3': 3411, 'WD_degree': 2178, 'WS_m/s': 2208, 'Xylene_ug/m3': 18443, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: JK
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/JK/*.csv
# Total Rows: 16792
# Total Columns: 19
# Mean of each feature column:
# {'co_mg/m3': 0.24991960457357743, 'nh3_ug/m3': 28.305119699859382, 'no2_ug/m3': 12.996924130539542, 'no_ug/m3': 7.370703906621302, 'nox_ppb': 16.34545795616962, 'ozone_ug/m3': 6.935063720819268, 'pm10_ug/m3': 66.25011076702985, 'pm2_5_ug/m3': 24.38629347308227, 'rf_mm': 0.0, 'rh_%': 71.19080514530684, 'so2_ug/m3': 8.816808599333013, 'sr_w/mt2': 105.37024118628372, 'temp_degree_c': 14.771457241544379, 'toluene_ug/m3': 3.2719681991422944, 'wd_degree': 170.09692949023426, 'ws_m/s': 0.3284385421629316}
# Number of null values per column:
# {'co_mg/m3': 0, 'from_date': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rf_mm': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'temp_degree_c': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'wd_degree': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: KA
# Processing files matching: file:///home/talentum/myproject/dataSource/output/KA/*.csv
# Total Rows: 1332059
# Total Columns: 27
# Mean of each feature column:
# {'BP_mmHg': 363.7137176872509, 'Benzene_ug/m3': 15.36920179772195, 'CH4_ug/m3': 4.517156734337505, 'CO_mg/m3': 2.856143085502091, 'Eth-Benzene_ug/m3': 8.50192150273313, 'MP-Xylene_ug/m3': 30.25980181795127, 'NH3_ug/m3': 11.756515942453676, 'NO2_ug/m3': 20.33734699282512, 'NO_ug/m3': 11.550350253047231, 'NOx_ppb': 21.01485710042116, 'O_Xylene_ug/m3': 42.000077383765024, 'Ozone_ug/m3': 27.52579360750042, 'PM10_ug/m3': 59.00541077282784, 'PM2_5_ug/m3': 35.52640579109481, 'RH_%': 60.663679833994834, 'SO2_ug/m3': 10.445414182724246, 'SR_W/mt2': 395.6134363853555, 'THC_ug/m3': 23.876607990452946, 'Temp_degree_C': 47.591172909170915, 'Toluene_ug/m3': 21.97143495737886, 'VWS_m/s': 217.8325528429488, 'WD_deg': 440.0721744261235, 'WS_m/s': 256.53754213958865}
# Number of null values per column:
# {'BP_mmHg': 938871, 'Benzene_ug/m3': 695704, 'CH4_ug/m3': 1322897, 'CO_mg/m3': 394312, 'Eth-Benzene_ug/m3': 1082114, 'From_Date': 0, 'MP-Xylene_ug/m3': 954931, 'NH3_ug/m3': 471746, 'NMHC_': 1332059, 'NO2_ug/m3': 312597, 'NO_ug/m3': 348256, 'NOx_ppb': 315366, 'O_Xylene_ug/m3': 877054, 'Ozone_ug/m3': 439294, 'PM10_ug/m3': 555754, 'PM2_5_ug/m3': 458718, 'RH_%': 533061, 'SO2_ug/m3': 424899, 'SR_W/mt2': 898071, 'THC_ug/m3': 1295190, 'Temp_degree_C': 763217, 'To_Date': 0, 'Toluene_ug/m3': 683761, 'VWS_m/s': 1079944, 'WD_deg': 761766, 'WS_m/s': 536310, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: KA
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/KA/*.csv
# Total Rows: 1087206
# Total Columns: 19
# Mean of each feature column:
# {'benzene_ug/m3': 0.30969376548616295, 'co_mg/m3': 0.5457473744626267, 'nh3_ug/m3': 8.950146375192798, 'no2_ug/m3': 16.719598935250637, 'no_ug/m3': 6.08342234130725, 'nox_ppb': 15.662255460337528, 'o_xylene_ug/m3': 34.652471040448006, 'ozone_ug/m3': 22.63742732290041, 'pm10_ug/m3': 51.03182441972455, 'pm2_5_ug/m3': 28.140414539623563, 'rh_%': 32.79911049053755, 'so2_ug/m3': 7.078950649650782, 'temp_degree_c': 48.0244095691157, 'toluene_ug/m3': 0.9753537967984215, 'wd_deg': 362.7929504341708, 'ws_m/s': 235.41574850577726}
# Number of null values per column:
# {'benzene_ug/m3': 0, 'co_mg/m3': 0, 'from_date': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'o_xylene_ug/m3': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'temp_degree_c': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'wd_deg': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: KL
# Processing files matching: file:///home/talentum/myproject/dataSource/output/KL/*.csv
# Total Rows: 272404
# Total Columns: 20
# Mean of each feature column:
# {'AT_degree_C': 139.87001057438246, 'BP_mmHg': 242.46961090091492, 'CO_mg/m3': 0.8047855610124732, 'NH3_ug/m3': 9.889364226904666, 'NO2_ug/m3': 14.621491725571584, 'NO_ug/m3': 15.803261161664704, 'NOx_ppb': 25.670743231619916, 'Ozone_ug/m3': 20.328025962288024, 'PM10_ug/m3': 57.183821673867754, 'PM2_5_ug/m3': 29.801123825055942, 'RF_mm': 165.15559846114638, 'RH_%': 16.293622115521575, 'SO2_ug/m3': 6.078362021893492, 'SR_W/mt2': 76.95164231918251, 'Temp_degree_C': 23.03450145800506, 'WD_deg': 88.04881174022009, 'WS_m/s': 73.7968164107572}
# Number of null values per column:
# {'AT_degree_C': 126769, 'BP_mmHg': 129150, 'CO_mg/m3': 28675, 'From_Date': 0, 'NH3_ug/m3': 38720, 'NO2_ug/m3': 31904, 'NO_ug/m3': 30527, 'NOx_ppb': 28254, 'Ozone_ug/m3': 31208, 'PM10_ug/m3': 40032, 'PM2_5_ug/m3': 44308, 'RF_mm': 112285, 'RH_%': 53300, 'SO2_ug/m3': 41650, 'SR_W/mt2': 74300, 'Temp_degree_C': 38522, 'To_Date': 0, 'WD_deg': 136188, 'WS_m/s': 129449, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: KL
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/KL/*.csv
# Total Rows: 264335
# Total Columns: 20
# Mean of each feature column:
# {'at_degree_c': 134.88104484831743, 'bp_mmhg': 132.51274957910138, 'co_mg/m3': 0.7385567934629232, 'nh3_ug/m3': 6.298145497192242, 'no2_ug/m3': 13.167672688064835, 'no_ug/m3': 9.185414757787116, 'nox_ppb': 21.25182953449404, 'ozone_ug/m3': 18.274113568011792, 'pm10_ug/m3': 52.68548947358459, 'pm2_5_ug/m3': 26.639242211587526, 'rf_mm': 103.05711899678253, 'rh_%': 0.5495024873736342, 'so2_ug/m3': 4.06406272343844, 'sr_w/mt2': 46.87499513873516, 'temp_degree_c': 9.795331265249503, 'wd_deg': 55.98716609608765, 'ws_m/s': 40.709351618228695}
# Number of null values per column:
# {'at_degree_c': 0, 'bp_mmhg': 0, 'co_mg/m3': 0, 'from_date': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rf_mm': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'temp_degree_c': 0, 'to_date': 0, 'wd_deg': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: MH
# Processing files matching: file:///home/talentum/myproject/dataSource/output/MH/*.csv
# Total Rows: 1536739
# Total Columns: 23
# Mean of each feature column:
# {'BP_mmHg': 197.4104637567879, 'Benzene_ug/m3': 26.106309109915188, 'CO_mg/m3': 11.866599856717016, 'MP-Xylene_ug/m3': 23.56201195251583, 'NO2_ug/m3': 27.903954847638936, 'NO_ug/m3': 22.695082777588897, 'NOx_ppb': 41.73944412779013, 'Ozone_ug/m3': 5.7614167718991105, 'PM10_ug/m3': 103.1053070694944, 'PM2_5_ug/m3': 47.13639505837645, 'RF_mm': 13.865519310166691, 'RH_%': 26.970945276838435, 'SO2_ug/m3': 21.855948318142282, 'SR_W/mt2': 83.81281940068155, 'Temp_degree_C': 64.69683434374794, 'Toluene_ug/m3': 6.13639581580457, 'VWS_m/s': 313.013468060583, 'WD_deg': 33.52384784353043, 'WS_m/s': 37.41561258215741, 'Xylene_ug/m3': 300.858315175115}
# Number of null values per column:
# {'BP_mmHg': 814507, 'Benzene_ug/m3': 550462, 'CO_mg/m3': 394943, 'From_Date': 0, 'MP-Xylene_ug/m3': 985558, 'NO2_ug/m3': 507114, 'NO_ug/m3': 505240, 'NOx_ppb': 420907, 'Ozone_ug/m3': 429673, 'PM10_ug/m3': 488149, 'PM2_5_ug/m3': 520312, 'RF_mm': 1118203, 'RH_%': 776549, 'SO2_ug/m3': 539716, 'SR_W/mt2': 625595, 'Temp_degree_C': 855171, 'To_Date': 0, 'Toluene_ug/m3': 594240, 'VWS_m/s': 992083, 'WD_deg': 693160, 'WS_m/s': 820582, 'Xylene_ug/m3': 1144906, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: MH
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/MH/*.csv
# Total Rows: 1264555
# Total Columns: 21
# Mean of each feature column:
# {'bp_mmhg': 124.20011685533487, 'benzene_ug/m3': 17.36176084866205, 'co_mg/m3': 7.926411876111952, 'mp-xylene_ug/m3': 3.70614737198161, 'no2_ug/m3': 19.72340367166143, 'no_ug/m3': 10.37077446214954, 'nox_ppb': 29.878592168798235, 'ozone_ug/m3': 0.8163356358547134, 'pm10_ug/m3': 90.09353817736296, 'pm2_5_ug/m3': 40.138148945662834, 'rh_%': 7.416323781869222, 'so2_ug/m3': 13.242489128602314, 'sr_w/mt2': 71.08761810283485, 'temp_degree_c': 5.214384941743096, 'toluene_ug/m3': 1.574513334728436, 'vws_m/s': 237.4059055557142, 'wd_deg': 28.948975426136357, 'ws_m/s': 33.48544045933359}
# Number of null values per column:
# {'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'from_date': 0, 'mp-xylene_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'temp_degree_c': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'vws_m/s': 0, 'wd_deg': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: ML
# Processing files matching: file:///home/talentum/myproject/dataSource/output/ML/*.csv
# Total Rows: 39833
# Total Columns: 26
# Mean of each feature column:
# {'AT_degree_C': 8.492658268218747, 'BP_mmHg': 853.5542786069641, 'Benzene_ug/m3': 12.768618363478607, 'CO_mg/m3': 0.1995305351104038, 'Eth-Benzene_ug/m3': 30.756084635913023, 'MP-Xylene_ug/m3': 21.13803267411831, 'NH3_ug/m3': 2.7700565242711854, 'NO2_ug/m3': 4.272939180592069, 'NO_ug/m3': 8.87698020833335, 'NOx_ppb': 4.616049873988594, 'O_Xylene_ug/m3': 33.01238300315766, 'Ozone_ug/m3': 17.02089370033405, 'PM10_ug/m3': 32.93206686930079, 'PM2_5_ug/m3': 21.95162514324519, 'RF_mm': 0.1086802050473195, 'RH_%': 59.85155632331667, 'SO2_ug/m3': 10.859521243947365, 'SR_W/mt2': 78.60298009429073, 'Toluene_ug/m3': 17.04887838037605, 'WD_degree': 151.2952731393142, 'WS_m/s': 4.201470351920289, 'Xylene_ug/m3': 20.71975079533408}
# Number of null values per column:
# {'AT_degree_C': 21020, 'BP_mmHg': 36014, 'Benzene_ug/m3': 12409, 'CO_mg/m3': 9671, 'Eth-Benzene_ug/m3': 31964, 'From_Date': 0, 'MP-Xylene_ug/m3': 28203, 'NH3_ug/m3': 10642, 'NO2_ug/m3': 16255, 'NO_ug/m3': 11033, 'NOx_ppb': 9677, 'O_Xylene_ug/m3': 32867, 'Ozone_ug/m3': 13784, 'PM10_ug/m3': 15816, 'PM2_5_ug/m3': 16272, 'RF_mm': 14473, 'RH_%': 14941, 'SO2_ug/m3': 10507, 'SR_W/mt2': 20743, 'To_Date': 0, 'Toluene_ug/m3': 19532, 'VWS_m/s': 39833, 'WD_degree': 14681, 'WS_m/s': 14941, 'Xylene_ug/m3': 36061, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: ML
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/ML/*.csv
# Total Rows: 30422
# Total Columns: 20
# Mean of each feature column:
# {'at_degree_c': 8.430545329037178, 'benzene_ug/m3': 0.009910262310169962, 'co_mg/m3': 0.16834527644467676, 'nh3_ug/m3': 2.6584889224903026, 'no2_ug/m3': 2.3490414831374897, 'no_ug/m3': 1.0215025310629424, 'nox_ppb': 0.6882499506935184, 'ozone_ug/m3': 13.770304713693577, 'pm10_ug/m3': 23.88186016698505, 'pm2_5_ug/m3': 15.599715008877014, 'rf_mm': 0.0, 'rh_%': 59.98760568010391, 'so2_ug/m3': 9.749794556570674, 'sr_w/mt2': 27.57362862402885, 'toluene_ug/m3': 0.008652291105121347, 'wd_degree': 150.76448885673793, 'ws_m/s': 3.58618105318511}
# Number of null values per column:
# {'at_degree_c': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'from_date': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rf_mm': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'wd_degree': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: MN
# Processing files matching: file:///home/talentum/myproject/dataSource/output/MN/*.csv
# Total Rows: 16654
# Total Columns: 25
# Mean of each feature column:
# {'AT_degree_C': 22.579713486595235, 'BP_mmHg': 700.2714285714286, 'Benzene_ug/m3': 0.3820317736962115, 'CO_mg/m3': 0.2727081378200875, 'Eth-Benzene_ug/m3': 0.32847988177605264, 'MP-Xylene_ug/m3': 0.5808614912035743, 'NH3_ug/m3': 7.8211177028949885, 'NO2_ug/m3': 7.716363941694068, 'NO_ug/m3': 3.929841472425601, 'NOx_ppb': 11.607120257407125, 'Ozone_ug/m3': 47.18745122363833, 'PM10_ug/m3': 62.94904245709152, 'PM2_5_ug/m3': 28.20303060427463, 'RF_mm': 0.031215310363319416, 'RH_%': 74.36013302408051, 'SO2_ug/m3': 48.58936517533253, 'SR_W/mt2': 53.837523126424806, 'WD_degree': 184.68039975441786, 'WS_m/s': 0.8184855720035469}
# Number of null values per column:
# {'AT_degree_C': 1995, 'BP_mmHg': 16647, 'Benzene_ug/m3': 1736, 'CO_mg/m3': 1736, 'Eth-Benzene_ug/m3': 1767, 'From_Date': 0, 'MP-Xylene_ug/m3': 9492, 'NH3_ug/m3': 4012, 'NO2_ug/m3': 1767, 'NO_ug/m3': 1767, 'NOx_ppb': 1736, 'O_Xylene_ug/m3': 16654, 'Ozone_ug/m3': 7787, 'PM10_ug/m3': 2263, 'PM2_5_ug/m3': 2571, 'RF_mm': 1736, 'RH_%': 1995, 'SO2_ug/m3': 1768, 'SR_W/mt2': 1736, 'To_Date': 0, 'Toluene_ug/m3': 16654, 'WD_degree': 1995, 'WS_m/s': 1995, 'Xylene_ug/m3': 16654, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: MN
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/MN/*.csv
# Total Rows: 14918
# Total Columns: 21
# Mean of each feature column:
# {'at_degree_c': 22.656657058587136, 'benzene_ug/m3': 0.24984850516154739, 'co_mg/m3': 0.17744603834296363, 'eth-benzene_ug/m3': 0.21399651427805544, 'mp-xylene_ug/m3': 0.4235534253921941, 'nh3_ug/m3': 8.068459579032236, 'no2_ug/m3': 6.101865531572473, 'no_ug/m3': 3.132928006435206, 'nox_ppb': 9.448861107386737, 'ozone_ug/m3': 39.031245475264924, 'pm10_ug/m3': 47.80066832014905, 'pm2_5_ug/m3': 17.34823501809938, 'rf_mm': 0.0, 'rh_%': 74.4292297895158, 'so2_ug/m3': 48.58104437592172, 'sr_w/mt2': 0.06333355677704856, 'wd_degree': 184.74404142646483, 'ws_m/s': 0.7344784823703006}
# Number of null values per column:
# {'at_degree_c': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'eth-benzene_ug/m3': 0, 'from_date': 0, 'mp-xylene_ug/m3': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rf_mm': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'to_date': 0, 'wd_degree': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: MP
# Processing files matching: file:///home/talentum/myproject/dataSource/output/MP/*.csv
# Total Rows: 617613
# Total Columns: 24
# Mean of each feature column:
# {'AT_degree_C': 22.915665521569498, 'Benzene_ug/m3': 15.420515089585981, 'CO_mg/m3': 7.373976532693195, 'Eth-Benzene_ug/m3': 49.73494555777336, 'MP-Xylene_ug/m3': 118.79613355561233, 'NH3_ug/m3': 14.501309206405075, 'NO2_ug/m3': 23.495221662155622, 'NO_ug/m3': 12.71213123650936, 'NOx_ppb': 22.5943351599606, 'O_Xylene_ug/m3': 351.0406200501395, 'Ozone_ug/m3': 39.7930017160015, 'PM10_ug/m3': 118.83369427232562, 'PM2_5_ug/m3': 48.16907799561273, 'RF_mm': 7.820385471750629, 'RH_%': 40.198450665100246, 'SO2_ug/m3': 13.691901244527406, 'SR_W/mt2': 230.2890523088597, 'Temp_degree_C': 113.56989653235765, 'Toluene_ug/m3': 14.845507424298281, 'WD_deg': 158.4992850838146, 'WS_m/s': 51.763113502694964}
# ...
# Number of null values per column:
# {'AT_degree_C': 89065, 'BP_mmHg': 59289, 'Benzene_ug/m3': 53008, 'CO_mg/m3': 69010, 'From_Date': 0, 'NO2_ug/m3': 49724, 'NO_ug/m3': 56308, 'NOx_ppb': 49610, 'Ozone_ug/m3': 62528, 'PM2_5_ug/m3': 82006, 'RH_%': 47122, 'SO2_ug/m3': 45738, 'SR_W/mt2': 100697, 'Temp_degree_C': 88981, 'To_Date': 0, 'Toluene_ug/m3': 59820, 'VWS_m/s': 51487, 'WD_deg': 51961, 'WS_m/s': 54655, 'Xylene_ug/m3': 102498, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: TG
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/TG/*.csv
# Total Rows: 390250
# Total Columns: 21
# Mean of each feature column:
# {'at_degree_c': 548.1361933888551, 'bp_mmhg': 274.0174972197302, 'benzene_ug/m3': 0.48691559256881844, 'co_mg/m3': 9.383167405507715, 'no2_ug/m3': 5.859853222293239, 'no_ug/m3': 67.49667818065335, 'nox_ppb': 22.473607379885152, 'ozone_ug/m3': 7.093416399744947, 'pm2_5_ug/m3': 39.003412351055175, 'rh_%': 14.612677770659447, 'so2_ug/m3': 13.322309801409604, 'sr_w/mt2': 1.4426449711723826, 'temp_degree_c': 0.76478385650189, 'toluene_ug/m3': 17.747971582319163, 'vws_m/s': 13.35611948750849, 'wd_deg': 57.50582752080633, 'ws_m/s': 19.63815656630287, 'xylene_ug/m3': -0.0017595387572067567}
# Number of null values per column:
# {'at_degree_c': 0, 'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'from_date': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'temp_degree_c': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'vws_m/s': 0, 'wd

# Processing files matching: file:///home/talentum/myproject/dataSource/output/TR/*.csv
# Total Rows: 30134
# Total Columns: 24
# Mean of each feature column:
# {'AT_degree_C': 20.845096352819393, 'BP_mmHg': 532.9219520897013, 'Benzene_ug/m3': 0.5159211722357615, 'CO_mg/m3': 0.710796249698387, 'Eth-Benzene_ug/m3': 1.5688596240099257, 'MP-Xylene_ug/m3': 1.501505367729533, 'NH3_ug/m3': 11.010542866028528, 'NO2_ug/m3': 11.067495499238394, 'NO_ug/m3': 4.08888223898153, 'NOx_ppb': 15.791841497466333, 'Ozone_ug/m3': 15.596959855334658, 'PM10_ug/m3': 95.20578234040964, 'PM2_5_ug/m3': 56.68848867264713, 'RF_mm': 0.0010857113893253632, 'RH_%': 51.44084792086923, 'SO2_ug/m3': 25.244057561079135, 'SR_W/mt2': 103.7904584109087, 'WD_degree': 111.2745747136844, 'WS_m/s': 23.41530008147001, 'Xylene_ug/m3': 749.8339762158867}
# Number of null values per column:
# {'AT_degree_C': 14670, 'BP_mmHg': 8552, 'Benzene_ug/m3': 2631, 'CO_mg/m3': 1123, 'Eth-Benzene_ug/m3': 19655, 'From_Date': 0, 'MP-Xylene_ug/m3': 17652, 'NH3_ug/m3': 1195, 'NO2_ug/m3': 1250, 'NO_ug/m3': 1228, 'NOx_ppb': 1125, 'Ozone_ug/m3': 2484, 'PM10_ug/m3': 2908, 'PM2_5_ug/m3': 3826, 'RF_mm': 10405, 'RH_%': 14767, 'SO2_ug/m3': 1851, 'SR_W/mt2': 10261, 'To_Date': 0, 'Toluene_ug/m3': 30134, 'WD_degree': 8043, 'WS_m/s': 8040, 'Xylene_ug/m3': 23575, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: TR
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/TR/*.csv
# Total Rows: 29013
# Total Columns: 21
# Mean of each feature column:
# {'at_degree_c': 20.607733429846302, 'bp_mmhg': 589.9301027125745, 'benzene_ug/m3': 0.15239203115844857, 'co_mg/m3': 0.6289718402095713, 'mp-xylene_ug/m3': 0.4319649812154254, 'nh3_ug/m3': 10.026100713473175, 'no2_ug/m3': 8.813358839140928, 'no_ug/m3': 1.7148867748940073, 'nox_ppb': 11.461026091752103, 'ozone_ug/m3': 9.491081928791104, 'pm10_ug/m3': 82.32987488366962, 'pm2_5_ug/m3': 49.847681728881696, 'rf_mm': 0.0, 'rh_%': 51.77866439181996, 'so2_ug/m3': 17.10584944679878, 'sr_w/mt2': 97.4499638093222, 'wd_degree': 114.43470409816662, 'ws_m/s': 17.94570571812532}
# Number of null values per column:
# {'at_degree_c': 0, 'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'from_date': 0, 'mp-xylene_ug/m3': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rf_mm': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'to_date': 0, 'wd_degree': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: UK
# Processing files matching: file:///home/talentum/myproject/dataSource/output/UK/*.csv
# Total Rows: 10560
# Total Columns: 17
# Mean of each feature column:
# {'AT_degree': 19.915841613525135, 'BP_mmHg': 590.4301298371089, 'CO_mg/m3': 1.863504293612514, 'NO2_ug/m3': 6.035587551652897, 'NO_ug/m3': 1.541447368421052, 'NOx_ppb': 4.896195104813225, 'Ozone_ug/m3': 31.26627111984296, 'PM10_ug/m3': 82.02641723648601, 'PM2_5_ug/m3': 35.78421412007221, 'RH_%': 57.24966302250817, 'SO2_ug/m3': 14.612714030155852, 'SR_W/mt2': 84.85086977073928, 'WD_degree': 143.06092973110069, 'WS_m/s': 1.6511192986914185}
# Number of null values per column:
# {'AT_degree': 3817, 'BP_mmHg': 2704, 'CO_mg/m3': 2059, 'From_Date': 0, 'NO2_ug/m3': 2816, 'NO_ug/m3': 2808, 'NOx_ppb': 2021, 'Ozone_ug/m3': 2925, 'PM10_ug/m3': 2809, 'PM2_5_ug/m3': 2798, 'RH_%': 2785, 'SO2_ug/m3': 2734, 'SR_W/mt2': 2098, 'To_Date': 0, 'WD_degree': 2676, 'WS_m/s': 2689, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: UK
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/UK/*.csv
# Total Rows: 10560
# Total Columns: 17
# Mean of each feature column:
# {'at_degree': 20.882438446968496, 'bp_mmhg': 644.154172348569, 'co_mg/m3': 0.47617329545451353, 'no2_ug/m3': 2.8178446969698068, 'no_ug/m3': 0.469860795454529, 'nox_ppb': 2.986196022727376, 'ozone_ug/m3': 24.77315719697009, 'pm10_ug/m3': 76.17817708333214, 'pm2_5_ug/m3': 30.449306818181228, 'rh_%': 58.24929261363602, 'so2_ug/m3': 6.91046496212138, 'sr_w/mt2': 13.455566287879025, 'wd_degree': 147.97176231059663, 'ws_m/s': 1.2519384469695995}
# Number of null values per column:
# {'at_degree': 0, 'bp_mmhg': 0, 'co_mg/m3': 0, 'from_date': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'to_date': 0, 'wd_degree': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: UP
# Processing files matching: file:///home/talentum/myproject/dataSource/output/UP/*.csv
# Total Rows: 1894072
# Total Columns: 24
# Mean of each feature column:
# {'AT_degree_C': 18.856224549312937, 'BP_mmHg': 517.830775562207, 'Benzene_ug/m3': 2.9906690236633198, 'CO_mg/m3': 7.98171781468401, 'Eth-Benzene_ug/m3': 19.205917696977917, 'MP-Xylene_ug/m3': 55.24950282261435, 'NH3_ug/m3': 28.010850338910178, 'NO2_ug/m3': 33.720298003739366, 'NO_ug/m3': 14.991626917945924, 'NOx_ppb': 32.8546567313726, 'O_Xylene_ug/m3': 76.83002244595141, 'Ozone_ug/m3': 27.08709086258017, 'PM10_ug/m3': 168.69081185154093, 'PM2_5_ug/m3': 86.16326055869241, 'RH_%': 174.11108859772742, 'SO2_ug/m3': 12.997456051268399, 'SR_W/mt2': 140.19518478327737, 'Toluene_ug/m3': 23.270403766546035, 'VWS_m/s': 219.49685492290334, 'WD_deg': 156.9124940015889, 'WS_m/s': 129.40042559468063}
# Number of null values per column:
# {'AT_degree_C': 1117423, 'BP_mmHg': 705012, 'Benzene_ug/m3': 684623, 'CO_mg/m3': 494311, 'Eth-Benzene_ug/m3': 1090675, 'From_Date': 0, 'MP-Xylene_ug/m3': 1058676, 'NH3_ug/m3': 506684, 'NO2_ug/m3': 347380, 'NO_ug/m3': 341695, 'NOx_ppb': 357127, 'O_Xylene_ug/m3': 874734, 'Ozone_ug/m3': 533655, 'PM10_ug/m3': 742593, 'PM2_5_ug/m3': 504577, 'RH_%': 470672, 'SO2_ug/m3': 397328, 'SR_W/mt2': 617766, 'To_Date': 0, 'Toluene_ug/m3': 877544, 'VWS_m/s': 1320315, 'WD_deg': 436595, 'WS_m/s': 459491, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: UP
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/UP/*.csv
# Total Rows: 1641091
# Total Columns: 23
# Mean of each feature column:
# {'at_degree_c': 20.654438754347623, 'bp_mmhg': 579.0262709319608, 'benzene_ug/m3': 0.8688934312577876, 'co_mg/m3': 1.1612934809813422, 'eth-benzene_ug/m3': 7.524655317696342, 'mp-xylene_ug/m3': 14.716552646927227, 'nh3_ug/m3': 24.135583602640306, 'no2_ug/m3': 26.361516990818153, 'no_ug/m3': 5.350310494669852, 'nox_ppb': 21.878504720313497, 'o_xylene_ug/m3': 30.507241816573224, 'ozone_ug/m3': 17.530674545136424, 'pm10_ug/m3': 141.5129911933664, 'pm2_5_ug/m3': 65.17851723020523, 'rh_%': 57.822093990985344, 'so2_ug/m3': 10.284068768878221, 'sr_w/mt2': 57.43722943449735, 'toluene_ug/m3': 16.11268512233567, 'wd_deg': 106.6662855867842, 'ws_m/s': 7.667257482989207}
# Number of null values per column:
# {'at_degree_c': 0, 'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'eth-benzene_ug/m3': 0, 'from_date': 0, 'mp-xylene_ug/m3': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'o_xylene_ug/m3': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'wd_deg': 0, 'ws_m/s': 0, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output for state code: WB
# Processing files matching: file:///home/talentum/myproject/dataSource/output/WB/*.csv
# Total Rows: 635495
# Total Columns: 26
# Mean of each feature column:
# {'AT_degree_C': 8.020123709893506, 'BP_mmHg': 428.24450361444235, 'Benzene_ug/m3': 7.963795942248666, 'CO_mg/m3': 0.7407113688088467, 'Eth-Benzene_ug/m3': 2.0239412470258182, 'MP-Xylene_ug/m3': 21.849833778018045, 'NH3_ug/m3': 20.49955653647884, 'NO2_ug/m3': 29.147993148536475, 'NO_ug/m3': 16.20067669654031, 'NOx_ppb': 43.908369322354716, 'O_Xylene_ug/m3': 41.945263074942766, 'Ozone_ug/m3': 29.836115829802534, 'PM10_ug/m3': 114.56039621216136, 'PM2_5_ug/m3': 57.87232833442706, 'RF_mm': 11.395373656359782, 'RH_%': 56.39901823558636, 'SO2_ug/m3': 11.817960362491494, 'SR_W/mt2': 280.6953862849659, 'Temp_': 131.13775070828527, 'Toluene_ug/m3': 17.644566208812517, 'VWS_m/s': 4.566153381197707, 'WD_degree': 202.42876770471074, 'WS_m/s': 87.02394739064778}
# Number of null values per column:
# {'AT_degree_C': 421850, 'BP_mmHg': 355229, 'Benzene_ug/m3': 223592, 'CO_mg/m3': 109987, 'Eth-Benzene_ug/m3': 330353, 'From_Date': 0, 'MP-Xylene_ug/m3': 232961, 'NH3_ug/m3': 176517, 'NO2_ug/m3': 119109, 'NO_ug/m3': 119769, 'NOx_ppb': 115429, 'O_Xylene_ug/m3': 369012, 'Ozone_ug/m3': 118167, 'PM10_ug/m3': 100731, 'PM2_5_ug/m3': 172327, 'RF_mm': 502833, 'RH_%': 174254, 'SO2_ug/m3': 97772, 'SR_W/mt2': 324041, 'Temp_': 309708, 'To_Date': 0, 'Toluene_ug/m3': 228087, 'VWS_m/s': 309575, 'WD_degree': 212585, 'WS_m/s': 197436, 'state': 0}
#
# ******************************************************************************************
# Processing base path: file:///home/talentum/myproject/dataSource/output/Cleaned for state code: WB
# Processing files matching: file:///home/talentum/myproject/dataSource/output/Cleaned/WB/*.csv
# Total Rows: 559152
# Total Columns: 24
# Mean of each feature column:
# {'bp_mmhg': 227.45902103529912, 'benzene_ug/m3': 4.17316722465316, 'co_mg/m3': 0.6037553473830825, 'eth-benzene_ug/m3': 0.812065180844506, 'mp-xylene_ug/m3': 1.5250974690250247, 'nh3_ug/m3': 16.849853867996643, 'no2_ug/m3': 23.855754696403746, 'no_ug/m3': 7.301672729422342, 'nox_ppb': 31.56964444372231, 'o_xylene_ug/m3': 11.942666895598167, 'ozone_ug/m3': 24.14126954746156, 'pm10_ug/m3': 101.80970077902303, 'pm2_5_ug/m3': 49.38827250906629, 'rh_%': 45.410552390058236, 'so2_ug/m3': 9.080493819211759, 'sr_w/mt2': 177.3814073098026, 'temp_': 44.52900197081362, 'toluene_ug/m3': 7.0815321951767025, 'vws_m/s': 0.007442645291441066, 'wd_degree': 125.26686425147955, 'ws_m/s': 63.08062700305063}
# Number of null values per column:
# {'bp_mmhg': 0, 'benzene_ug/m3': 0, 'co_mg/m3': 0, 'eth-benzene_ug/m3': 0, 'from_date': 0, 'mp-xylene_ug/m3': 0, 'nh3_ug/m3': 0, 'no2_ug/m3': 0, 'no_ug/m3': 0, 'nox_ppb': 0, 'o_xylene_ug/m3': 0, 'ozone_ug/m3': 0, 'pm10_ug/m3': 0, 'pm2_5_ug/m3': 0, 'rh_%': 0, 'so2_ug/m3': 0, 'sr_w/mt2': 0, 'temp_': 0, 'to_date': 0, 'toluene_ug/m3': 0, 'vws_m/s': 0, 'wd_degree': 0, 'ws_m/s': 0, 'state': 0}

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.types import DoubleType, IntegerType
import os
import glob

# Initialize Spark session
spark = SparkSession.builder \
    .appName("OutlierDetection") \
    .getOrCreate()

def count_outliers_in_csv(file_path):
    """Count outliers in a given CSV file."""
    # Ensure the file path uses the correct prefix for local files
    if not file_path.startswith('file:///'):
        file_path = 'file://' + file_path

    # Read the CSV file into a DataFrame
    df = spark.read.option("header", "true").csv(file_path, inferSchema=True)

    # Function to identify and count outliers using the IQR method
    def count_outliers(df, column):
        # Calculate Q1 and Q3 using approxQuantile function
        quantiles = df.approxQuantile(column, [0.25, 0.75], 0.05)
        q1, q3 = quantiles
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr

        # Count outliers
        outliers = df.filter((col(column) < lower_bound) | (col(column) > upper_bound))
        outlier_count = outliers.count()

        return outlier_count

    # Dictionary to store the count of outliers for each column
    outlier_counts = {}

    # Apply the outlier counting function to numeric columns only
    for column in df.columns:
        dtype = df.schema[column].dataType
        if isinstance(dtype, (DoubleType, IntegerType)):
            outlier_count = count_outliers(df, column)
            outlier_counts[column] = outlier_count

    # Print the results
    for column, count in outlier_counts.items():
        if count > 0:
            print(f"Column '{column}' has {count} outlier(s).")
        else:
            print(f"Column '{column}' has no outliers.")

    return outlier_counts

def process_csv_files(base_path, state_codes):
    """Process all CSV files for the given state codes."""
    for state_code in state_codes:
        # Construct the directory path
        print("*"*20+f'{state_code}'+"*"*20)
        directory_path = os.path.join(base_path, state_code)
        print(f"Looking for files in directory: {directory_path}")  # Debugging line

        # Construct the search pattern for CSV files
        search_pattern = os.path.join(directory_path, '*.csv')
        print(f"Search pattern: {search_pattern}")  # Debugging line

        # List all CSV files in the directory
        csv_files = glob.glob(search_pattern)

        if not csv_files:
            print(f"No CSV files found in directory: {directory_path}")
            continue

        # Process each CSV file
        for file_path in csv_files:
            print(f"Processing file: {file_path}")
            try:
                outlier_counts = count_outliers_in_csv(file_path)
            except Exception as e:
                print(f"Error processing file {file_path}: {e}")

# Example usage
state_codes = list(state_dict.values()) # Replace with actual state codes
base_path = '/home/talentum/myproject/dataSource/output'  # Local base path

process_csv_files(base_path, state_codes)

# Stop the Spark session
spark.stop()
# Out:
# ********************AP********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/AP
# Search pattern: /home/talentum/myproject/dataSource/output/AP/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/AP/part-00000-bea4240b-0224-4c5a-a59e-1cf2f7877304-c000.csv
# Column 'AT_degree_C' has 127 outlier(s).
# Column 'BP_mmHg' has no outliers.
# Column 'Benzene_ug/m3' has 21443 outlier(s).
# Column 'CO_mg/m3' has 8297 outlier(s).
# Column 'NH3_ug/m3' has 5084 outlier(s).
# Column 'NO2_ug/m3' has 16565 outlier(s).
# Column 'NO_ug/m3' has 22226 outlier(s).
# Column 'NOx_ppb' has 12556 outlier(s).
# Column 'Ozone_ug/m3' has 9507 outlier(s).
# Column 'PM10_ug/m3' has 7771 outlier(s).
# Column 'PM2_5_ug/m3' has 8702 outlier(s).
# Column 'RF_mm' has 67013 outlier(s).
# Column 'RH_%' has 39 outlier(s).
# Column 'SO2_ug/m3' has 7084 outlier(s).
# Column 'SR_W/mt2' has 41066 outlier(s).
# Column 'Temp_degree_C' has 65 outlier(s).
# Column 'Toluene_ug/m3' has 21676 outlier(s).
# Column 'VWS_m/s' has 46537 outlier(s).
# Column 'WD_deg' has 2111 outlier(s).
# Column 'WS_m/s' has 73 outlier(s).
# Column 'Xylene_ug/m3' has no outliers.
# ********************AR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/AR
# Search pattern: /home/talentum/myproject/dataSource/output/AR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/AR/part-00000-35816e9a-e1f3-44ae-8f4c-960b47342f3d-c000.csv
# Column 'AT_degree_C' has 5 outlier(s).
# Column 'BP_mmHg' has 26 outlier(s).
# Column 'Benzene_ug/m3' has 827 outlier(s).
# Column 'CO_mg/m3' has 798 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 570 outlier(s).
# Column 'MP-Xylene_ug/m3' has 696 outlier(s).
# Column 'NH3_ug/m3' has 484 outlier(s).
# Column 'NO2_ug/m3' has 287 outlier(s).
# Column 'NO_ug/m3' has 1535 outlier(s).
# Column 'NOx_ppb' has 395 outlier(s).
# Column 'Ozone_ug/m3' has 752 outlier(s).
# Column 'PM10_ug/m3' has 635 outlier(s).
# Column 'PM2_5_ug/m3' has 362 outlier(s).
# Column 'RF_mm' has 553 outlier(s).
# Column 'RH_%' has 1 outlier(s).
# Column 'SO2_ug/m3' has no outliers.
# Column 'SR_W/mt2' has 262 outlier(s).
# Column 'WD_degree' has 22 outlier(s).
# Column 'WS_m/s' has 429 outlier(s).
# ********************AS********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/AS
# Search pattern: /home/talentum/myproject/dataSource/output/AS/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/AS/part-00000-bb8f2a72-dcff-4785-a314-def986cf44b8-c000.csv
# Column 'AT_degree_C' has 938 outlier(s).
# Column 'BP_mmHg' has 5317 outlier(s).
# Column 'Benzene_ug/m3' has 6985 outlier(s).
# Column 'CO_mg/m3' has 6286 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 2931 outlier(s).
# Column 'MP-Xylene_ug/m3' has 3609 outlier(s).
# Column 'NH3_ug/m3' has 4915 outlier(s).
# Column 'NO2_ug/m3' has 5434 outlier(s).
# Column 'NO_ug/m3' has 12836 outlier(s).
# Column 'NOx_ppb' has 8194 outlier(s).
# Column 'O_Xylene_ug/m3' has no outliers.
# Column 'Ozone_ug/m3' has 8615 outlier(s).
# Column 'PM10_ug/m3' has 4965 outlier(s).
# Column 'PM2_5_ug/m3' has 4862 outlier(s).
# Column 'RF_mm' has 6444 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 3749 outlier(s).
# Column 'SR_W/mt2' has 2651 outlier(s).
# Column 'Toluene_ug/m3' has 241 outlier(s).
# Column 'WD_degree' has 1600 outlier(s).
# Column 'WS_m/s' has 14001 outlier(s).
# ********************BR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/BR
# Search pattern: /home/talentum/myproject/dataSource/output/BR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/BR/part-00000-b3c9f37c-bf0f-41b0-a849-a455d4785c88-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'BP_mmHg' has 113154 outlier(s).
# Column 'Benzene_ug/m3' has 32372 outlier(s).
# Column 'CO_mg/m3' has 29658 outlier(s).
# Column 'NO2_ug/m3' has 69019 outlier(s).
# Column 'NO_ug/m3' has 11806 outlier(s).
# Column 'NOx_ppb' has 29294 outlier(s).
# Column 'Ozone_ug/m3' has 72636 outlier(s).
# Column 'PM2_5_ug/m3' has 22118 outlier(s).
# Column 'RH_%' has 114537 outlier(s).
# Column 'SO2_ug/m3' has 50256 outlier(s).
# Column 'SR_W/mt2' has 83983 outlier(s).
# Column 'Temp_' has 15991 outlier(s).
# Column 'Toluene_ug/m3' has 39233 outlier(s).
# Column 'VWS_m/s' has 58782 outlier(s).
# Column 'WD_deg' has 55448 outlier(s).
# Column 'WS_m/s' has 77393 outlier(s).
# Column 'Xylene_ug/m3' has 17222 outlier(s).
# ********************CG********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/CG
# Search pattern: /home/talentum/myproject/dataSource/output/CG/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/CG/part-00000-761ebdd3-d840-4fb5-81eb-a3b6d1635d7c-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'BP_mmHg' has no outliers.
# Column 'CO_mg/m3' has 3497 outlier(s).
# Column 'NO2_ug/m3' has 3151 outlier(s).
# Column 'NO_ug/m3' has 5936 outlier(s).
# Column 'NOx_ppb' has 4942 outlier(s).
# Column 'PM10_ug/m3' has 2995 outlier(s).
# Column 'PM2_5_ug/m3' has 3419 outlier(s).
# Column 'RF_mm' has 8485 outlier(s).
# Column 'RH_%' has 9821 outlier(s).
# Column 'SO2_ug/m3' has 2891 outlier(s).
# Column 'SR_W/mt2' has 4072 outlier(s).
# Column 'WD_degree' has 5064 outlier(s).
# Column 'WS_m/s' has 5155 outlier(s).
# ********************CH********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/CH
# Search pattern: /home/talentum/myproject/dataSource/output/CH/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/CH/part-00000-138dd893-b7fc-4ae0-9c8f-c860adecdf10-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'BP_mmHg' has 2894 outlier(s).
# Column 'Benzene_ug/m3' has 2040 outlier(s).
# Column 'CO_mg/m3' has 2561 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 5685 outlier(s).
# Column 'MP-Xylene_ug/m3' has 7919 outlier(s).
# Column 'NH3_ug/m3' has 4048 outlier(s).
# Column 'NO2_ug/m3' has 4019 outlier(s).
# Column 'NO_ug/m3' has 8988 outlier(s).
# Column 'NOx_ppb' has 6069 outlier(s).
# Column 'Ozone_ug/m3' has 3643 outlier(s).
# Column 'PM10_ug/m3' has 1304 outlier(s).
# Column 'PM2_5_ug/m3' has 2355 outlier(s).
# Column 'RF_mm' has 666 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 4284 outlier(s).
# Column 'SR_W/mt2' has 2775 outlier(s).
# Column 'Toluene_ug/m3' has 5235 outlier(s).
# Column 'VWS_m/s' has 2637 outlier(s).
# Column 'WD_degree' has no outliers.
# Column 'WS_m/s' has no outliers.
# Column 'Xylene_ug/m3' has 2893 outlier(s).
# ********************DL********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/DL
# Search pattern: /home/talentum/myproject/dataSource/output/DL/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/DL/part-00000-dbbd98e4-2caa-4e71-b53a-e96e0dbe66c6-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'BP_mmHg' has 222345 outlier(s).
# Column 'Benzene_ug/m3' has 155713 outlier(s).
# Column 'CO_mg/m3' has 149564 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 34566 outlier(s).
# Column 'MP-Xylene_ug/m3' has 19460 outlier(s).
# Column 'NH3_ug/m3' has 94612 outlier(s).
# Column 'NO2_ug/m3' has 72733 outlier(s).
# Column 'NO_ug/m3' has 263017 outlier(s).
# Column 'NOx_ppb' has 126911 outlier(s).
# Column 'O_Xylene_ug/m3' has 166754 outlier(s).
# Column 'Ozone_ug/m3' has 93376 outlier(s).
# Column 'PM10_ug/m3' has 65486 outlier(s).
# Column 'PM2_5_ug/m3' has 65910 outlier(s).
# Column 'RH_%' has 266082 outlier(s).
# Column 'SO2_ug/m3' has 121244 outlier(s).
# Column 'SR_W/mt2' has 279010 outlier(s).
# Column 'Temp_degree_C' has 38300 outlier(s).
# Column 'Toluene_ug/m3' has 110785 outlier(s).
# Column 'VWS_m/s' has 54396 outlier(s).
# Column 'WD_deg' has 24488 outlier(s).
# Column 'WS_m/s' has no outliers.
# Column 'Xylene_ug/m3' has 60 outlier(s).
# ********************GJ********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/GJ
# Search pattern: /home/talentum/myproject/dataSource/output/GJ/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/GJ/part-00000-33f83427-fcbf-41b3-a513-49cc942bd96e-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'BP_mmHg' has no outliers.
# Column 'Benzene_ug/m3' has 23491 outlier(s).
# Column 'CO_mg/m3' has 28686 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 2256 outlier(s).
# Column 'MP-Xylene_ug/m3' has 27168 outlier(s).
# Column 'NO2_ug/m3' has 30632 outlier(s).
# Column 'NO_ug/m3' has 35344 outlier(s).
# Column 'NOx_ppb' has 19261 outlier(s).
# Column 'O_Xylene_ug/m3' has 13917 outlier(s).
# Column 'Ozone_ug/m3' has 53789 outlier(s).
# Column 'PM10_ug/m3' has 12370 outlier(s).
# Column 'PM2_5_ug/m3' has 15429 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 23587 outlier(s).
# Column 'SR_W/mt2' has 10066 outlier(s).
# Column 'Toluene_ug/m3' has 24507 outlier(s).
# Column 'VWS_m/s' has 25681 outlier(s).
# Column 'WD_deg' has no outliers.
# Column 'WS_m/s' has no outliers.
# Column 'Xylene_ug/m3' has 31241 outlier(s).
# ********************HP********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/HP
# Search pattern: /home/talentum/myproject/dataSource/output/HP/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/HP/part-00000-346cec8f-2dff-4b9e-bf94-9e8d22a7d70f-c000.csv
# Column 'AT_degree_C' has 161 outlier(s).
# Column 'Benzene_ug/m3' has 832 outlier(s).
# Column 'CO_mg/m3' has 602 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 208 outlier(s).
# Column 'MP-Xylene_ug/m3' has 670 outlier(s).
# Column 'NH3_ug/m3' has 414 outlier(s).
# Column 'NO2_ug/m3' has 374 outlier(s).
# Column 'NO_ug/m3' has 1066 outlier(s).
# Column 'NOx_ppb' has 606 outlier(s).
# Column 'O_Xylene_ug/m3' has 888 outlier(s).
# Column 'Ozone_ug/m3' has 297 outlier(s).
# Column 'PM10_ug/m3' has 420 outlier(s).
# Column 'PM2_5_ug/m3' has 720 outlier(s).
# Column 'RF_mm' has 280 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 948 outlier(s).
# Column 'SR_W/mt2' has 102 outlier(s).
# Column 'Toluene_ug/m3' has 731 outlier(s).
# Column 'WD_degree' has no outliers.
# Column 'WS_m/s' has 361 outlier(s).
# ********************HR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/HR
# Search pattern: /home/talentum/myproject/dataSource/output/HR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/HR/part-00000-ed123c56-b7ea-4e4e-ae97-aefcee388ae8-c000.csv
# Column 'AT_degree_C' has 157810 outlier(s).
# Column 'BP_mmHg' has 113435 outlier(s).
# Column 'Benzene_ug/m3' has 146474 outlier(s).
# Column 'CO_mg/m3' has 46906 outlier(s).
# Column 'NO2_ug/m3' has 109022 outlier(s).
# Column 'NO_ug/m3' has 37360 outlier(s).
# Column 'NOx_ppb' has 74048 outlier(s).
# Column 'Ozone_ug/m3' has 91447 outlier(s).
# Column 'PM2_5_ug/m3' has 55752 outlier(s).
# Column 'RF_mm' has 29678 outlier(s).
# Column 'RH_%' has 53015 outlier(s).
# Column 'SO2_ug/m3' has 63323 outlier(s).
# Column 'SR_W/mt2' has 30631 outlier(s).
# Column 'Temp_degree_C' has 93174 outlier(s).
# Column 'Toluene_ug/m3' has 33078 outlier(s).
# Column 'VWS_m/s' has 2580 outlier(s).
# Column 'WD_deg' has 142248 outlier(s).
# Column 'WS_m/s' has 81763 outlier(s).
# Column 'Xylene_ug/m3' has 94936 outlier(s).
# ********************JH********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/JH
# Search pattern: /home/talentum/myproject/dataSource/output/JH/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/JH/part-00000-78b9c607-8c11-4cfe-a7c5-f15d423dc390-c000.csv
# Column 'BP_mmHg' has 417 outlier(s).
# Column 'Benzene_ug/m3' has 1300 outlier(s).
# Column 'CO_mg/m3' has 851 outlier(s).
# Column 'NH3_ug/m3' has 6021 outlier(s).
# Column 'NO2_ug/m3' has 1805 outlier(s).
# Column 'NO_ug/m3' has 5068 outlier(s).
# Column 'Ozone_ug/m3' has 2055 outlier(s).
# Column 'PM10_ug/m3' has 2028 outlier(s).
# Column 'PM2_5_ug/m3' has 318 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 2613 outlier(s).
# Column 'SR_W/mt2' has 1842 outlier(s).
# Column 'Temp_degree_C' has 153 outlier(s).
# Column 'VWS_m/s' has 2386 outlier(s).
# Column 'WD_deg' has 303 outlier(s).
# Column 'WS_m/s' has 47 outlier(s).
# ********************JK********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/JK
# Search pattern: /home/talentum/myproject/dataSource/output/JK/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/JK/part-00000-49d46d4d-5a61-475b-8eb0-808efcbba7d6-c000.csv
# Column 'Benzene_ug/m3' has 524 outlier(s).
# Column 'CO_mg/m3' has 1568 outlier(s).
# Column 'Eth-Benzene_ug/m3' has no outliers.
# Column 'NH3_ug/m3' has 1807 outlier(s).
# Column 'NO2_ug/m3' has 873 outlier(s).
# Column 'NO_ug/m3' has 315 outlier(s).
# Column 'NOx_ppb' has 439 outlier(s).
# Column 'Ozone_ug/m3' has 1743 outlier(s).
# Column 'PM10_ug/m3' has 1436 outlier(s).
# Column 'PM2_5_ug/m3' has 1155 outlier(s).
# Column 'RF_mm' has 776 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 1381 outlier(s).
# Column 'SR_W/mt2' has 1818 outlier(s).
# Column 'Temp_degree_C' has no outliers.
# Column 'Toluene_ug/m3' has 224 outlier(s).
# Column 'WD_degree' has 28 outlier(s).
# Column 'WS_m/s' has 758 outlier(s).
# Column 'Xylene_ug/m3' has 40 outlier(s).
# ********************KA********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/KA
# Search pattern: /home/talentum/myproject/dataSource/output/KA/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/KA/part-00000-7071ed92-d4a8-4529-99d5-192d1be7fc26-c000.csv
# Column 'BP_mmHg' has 9244 outlier(s).
# Column 'Benzene_ug/m3' has 107958 outlier(s).
# Column 'CH4_ug/m3' has 2090 outlier(s).
# Column 'CO_mg/m3' has 73726 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 49589 outlier(s).
# Column 'MP-Xylene_ug/m3' has 35793 outlier(s).
# Column 'NH3_ug/m3' has 40127 outlier(s).
# Column 'NO2_ug/m3' has 49559 outlier(s).
# Column 'NO_ug/m3' has 87354 outlier(s).
# Column 'NOx_ppb' has 73672 outlier(s).
# Column 'O_Xylene_ug/m3' has 56 outlier(s).
# Column 'Ozone_ug/m3' has 45217 outlier(s).
# Column 'PM10_ug/m3' has 15815 outlier(s).
# Column 'PM2_5_ug/m3' has 48915 outlier(s).
# Column 'RH_%' has 49178 outlier(s).
# Column 'SO2_ug/m3' has 32550 outlier(s).
# Column 'SR_W/mt2' has no outliers.
# Column 'THC_ug/m3' has 501 outlier(s).
# Column 'Temp_degree_C' has no outliers.
# Column 'Toluene_ug/m3' has 99287 outlier(s).
# Column 'VWS_m/s' has 66331 outlier(s).
# Column 'WD_deg' has no outliers.
# Column 'WS_m/s' has 1238 outlier(s).
# ********************KL********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/KL
# Search pattern: /home/talentum/myproject/dataSource/output/KL/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/KL/part-00000-9c2c22dd-f1d8-490c-ac67-fa4703c39dce-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'BP_mmHg' has no outliers.
# Column 'CO_mg/m3' has 10566 outlier(s).
# Column 'NH3_ug/m3' has 22127 outlier(s).
# Column 'NO2_ug/m3' has 8965 outlier(s).
# Column 'NO_ug/m3' has 22962 outlier(s).
# Column 'NOx_ppb' has 19832 outlier(s).
# Column 'Ozone_ug/m3' has 7681 outlier(s).
# Column 'PM10_ug/m3' has 10614 outlier(s).
# Column 'PM2_5_ug/m3' has 8733 outlier(s).
# Column 'RF_mm' has 7630 outlier(s).
# Column 'RH_%' has 1 outlier(s).
# Column 'SO2_ug/m3' has 16316 outlier(s).
# Column 'SR_W/mt2' has 15651 outlier(s).
# Column 'Temp_degree_C' has no outliers.
# Column 'WD_deg' has 26922 outlier(s).
# Column 'WS_m/s' has no outliers.
# ********************MH********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/MH
# Search pattern: /home/talentum/myproject/dataSource/output/MH/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/MH/part-00000-e287304f-81bb-4b6e-9966-8e5415ca2520-c000.csv
# Column 'BP_mmHg' has 62675 outlier(s).
# Column 'Benzene_ug/m3' has 94208 outlier(s).
# Column 'CO_mg/m3' has 65340 outlier(s).
# Column 'MP-Xylene_ug/m3' has 80063 outlier(s).
# Column 'NO2_ug/m3' has 48026 outlier(s).
# Column 'NO_ug/m3' has 149459 outlier(s).
# Column 'NOx_ppb' has 91118 outlier(s).
# Column 'Ozone_ug/m3' has 187308 outlier(s).
# Column 'PM10_ug/m3' has 37276 outlier(s).
# Column 'PM2_5_ug/m3' has 41092 outlier(s).
# Column 'RF_mm' has 238 outlier(s).
# Column 'RH_%' has 67819 outlier(s).
# Column 'SO2_ug/m3' has 84199 outlier(s).
# Column 'SR_W/mt2' has 4919 outlier(s).
# Column 'Temp_degree_C' has 102798 outlier(s).
# Column 'Toluene_ug/m3' has 105916 outlier(s).
# Column 'VWS_m/s' has 26 outlier(s).
# Column 'WD_deg' has 13896 outlier(s).
# Column 'WS_m/s' has 54 outlier(s).
# Column 'Xylene_ug/m3' has 4 outlier(s).
# ********************ML********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/ML
# Search pattern: /home/talentum/myproject/dataSource/output/ML/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/ML/part-00000-1621dcb3-9219-4f78-af97-025dbb595fd9-c000.csv
# Column 'AT_degree_C' has 54 outlier(s).
# Column 'BP_mmHg' has 82 outlier(s).
# Column 'Benzene_ug/m3' has 6945 outlier(s).
# Column 'CO_mg/m3' has 1360 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 1662 outlier(s).
# Column 'MP-Xylene_ug/m3' has 1943 outlier(s).
# Column 'NH3_ug/m3' has 328 outlier(s).
# Column 'NO2_ug/m3' has 3372 outlier(s).
# Column 'NO_ug/m3' has 7499 outlier(s).
# Column 'NOx_ppb' has 4174 outlier(s).
# Column 'O_Xylene_ug/m3' has 1071 outlier(s).
# Column 'Ozone_ug/m3' has 956 outlier(s).
# Column 'PM10_ug/m3' has 1923 outlier(s).
# Column 'PM2_5_ug/m3' has 2131 outlier(s).
# Column 'RF_mm' has 3058 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 2110 outlier(s).
# Column 'SR_W/mt2' has 2657 outlier(s).
# Column 'Toluene_ug/m3' has 4172 outlier(s).
# Column 'WD_degree' has 146 outlier(s).
# Column 'WS_m/s' has 1590 outlier(s).
# Column 'Xylene_ug/m3' has 240 outlier(s).
# ********************MN********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/MN
# Search pattern: /home/talentum/myproject/dataSource/output/MN/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/MN/part-00000-1256e008-54d3-472e-b420-4159fc435ebf-c000.csv
# Column 'AT_degree_C' has 277 outlier(s).
# Column 'BP_mmHg' has no outliers.
# Column 'Benzene_ug/m3' has 2188 outlier(s).
# Column 'CO_mg/m3' has 2178 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 2134 outlier(s).
# Column 'MP-Xylene_ug/m3' has 669 outlier(s).
# Column 'NH3_ug/m3' has 2015 outlier(s).
# Column 'NO2_ug/m3' has 2999 outlier(s).
# Column 'NO_ug/m3' has 1910 outlier(s).
# Column 'NOx_ppb' has 2527 outlier(s).
# Column 'Ozone_ug/m3' has 56 outlier(s).
# Column 'PM10_ug/m3' has 1390 outlier(s).
# Column 'PM2_5_ug/m3' has 1789 outlier(s).
# Column 'RF_mm' has 1119 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 2 outlier(s).
# Column 'SR_W/mt2' has 2979 outlier(s).
# Column 'WD_degree' has 148 outlier(s).
# Column 'WS_m/s' has 924 outlier(s).
# ********************MP********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/MP
# Search pattern: /home/talentum/myproject/dataSource/output/MP/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/MP/part-00000-ee7a6ebe-1d67-4459-aa45-884c71e76f7b-c000.csv
# Column 'AT_degree_C' has 16519 outlier(s).
# Column 'Benzene_ug/m3' has 5 outlier(s).
# Column 'CO_mg/m3' has 61952 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 147 outlier(s).
# Column 'MP-Xylene_ug/m3' has 8168 outlier(s).
# Column 'NH3_ug/m3' has 13319 outlier(s).
# Column 'NO2_ug/m3' has 30290 outlier(s).
# Column 'NO_ug/m3' has 46507 outlier(s).
# Column 'NOx_ppb' has 35311 outlier(s).
# Column 'O_Xylene_ug/m3' has no outliers.
# Column 'Ozone_ug/m3' has 13018 outlier(s).
# Column 'PM10_ug/m3' has 26826 outlier(s).
# Column 'PM2_5_ug/m3' has 27970 outlier(s).
# Column 'RF_mm' has 13 outlier(s).
# Column 'RH_%' has 17076 outlier(s).
# Column 'SO2_ug/m3' has 20951 outlier(s).
# Column 'SR_W/mt2' has 21 outlier(s).
# Column 'Temp_degree_C' has 55420 outlier(s).
# Column 'Toluene_ug/m3' has 41498 outlier(s).
# Column 'WD_deg' has 7429 outlier(s).
# Column 'WS_m/s' has 56603 outlier(s).
# ********************MZ********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/MZ
# Search pattern: /home/talentum/myproject/dataSource/output/MZ/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/MZ/part-00000-cea0985d-34da-45b5-99fb-e0994e7d79e4-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'BP_mmHg' has 535 outlier(s).
# Column 'Benzene_ug/m3' has 3497 outlier(s).
# Column 'CO_mg/m3' has 369 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 2650 outlier(s).
# Column 'MP-Xylene_ug/m3' has 3040 outlier(s).
# Column 'NH3_ug/m3' has 1189 outlier(s).
# Column 'NO2_ug/m3' has 2636 outlier(s).
# Column 'NO_ug/m3' has 29 outlier(s).
# Column 'NOx_ppb' has 21 outlier(s).
# Column 'Ozone_ug/m3' has 2867 outlier(s).
# Column 'PM10_ug/m3' has 1461 outlier(s).
# Column 'PM2_5_ug/m3' has 1549 outlier(s).
# Column 'RF_mm' has 209 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 17 outlier(s).
# Column 'SR_W/mt2' has 101 outlier(s).
# Column 'Toluene_ug/m3' has 283 outlier(s).
# Column 'WD_degree' has no outliers.
# Column 'WS_m/s' has 702 outlier(s).
# ********************NL********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/NL
# Search pattern: /home/talentum/myproject/dataSource/output/NL/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/NL/part-00000-e3fb1387-244a-47ec-aee5-cf34d4d7c925-c000.csv
# Column 'AT_degree_C' has 176 outlier(s).
# Column 'BP_mmHg' has 149 outlier(s).
# Column 'Benzene_ug/m3' has 1337 outlier(s).
# Column 'CO_mg/m3' has 1378 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 333 outlier(s).
# Column 'MP-Xylene_ug/m3' has 455 outlier(s).
# Column 'NH3_ug/m3' has 2429 outlier(s).
# Column 'NO2_ug/m3' has 992 outlier(s).
# Column 'NO_ug/m3' has 1138 outlier(s).
# Column 'NOx_ppb' has 1585 outlier(s).
# Column 'Ozone_ug/m3' has 2515 outlier(s).
# Column 'PM10_ug/m3' has 1064 outlier(s).
# Column 'PM2_5_ug/m3' has 1246 outlier(s).
# Column 'RF_mm' has 1675 outlier(s).
# Column 'RH_%' has 265 outlier(s).
# Column 'SO2_ug/m3' has 709 outlier(s).
# Column 'SR_W/mt2' has 311 outlier(s).
# Column 'WD_degree' has no outliers.
# Column 'WS_m/s' has 561 outlier(s).
# ********************OR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/OR
# Search pattern: /home/talentum/myproject/dataSource/output/OR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/OR/part-00000-9367b044-638a-4d39-ac55-59ea77bc99ba-c000.csv
# Column 'AT_degree_C' has 5876 outlier(s).
# Column 'Benzene_ug/m3' has 13547 outlier(s).
# Column 'CO_mg/m3' has 2910 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 1670 outlier(s).
# Column 'MP-Xylene_ug/m3' has 2471 outlier(s).
# Column 'NH3_ug/m3' has 3735 outlier(s).
# Column 'NO2_ug/m3' has 6606 outlier(s).
# Column 'NO_ug/m3' has 6941 outlier(s).
# Column 'NOx_ug/m3' has 8154 outlier(s).
# Column 'O_Xylene_ug/m3' has 1870 outlier(s).
# Column 'Ozone_ug/m3' has 7862 outlier(s).
# Column 'PM10_ug/m3' has 5777 outlier(s).
# Column 'PM2_5_ug/m3' has 2003 outlier(s).
# Column 'RF_mm' has no outliers.
# Column 'RH_degree' has no outliers.
# Column 'SO2_ug/m3' has 5598 outlier(s).
# Column 'SR_W/mt2' has 2845 outlier(s).
# Column 'Toluene_ug/m3' has 7027 outlier(s).
# Column 'WD_degree' has 135 outlier(s).
# Column 'WS_m/s' has 1470 outlier(s).
# Column 'Xylene_ug/m3' has 9 outlier(s).
# ********************PB********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/PB
# Search pattern: /home/talentum/myproject/dataSource/output/PB/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/PB/part-00000-26f705b7-c361-4c85-bc20-f670caef3015-c000.csv
# Column 'Benzene_ug/m3' has 43334 outlier(s).
# Column 'CO_mg/m3' has 22068 outlier(s).
# Column 'NH3_ug/m3' has 21719 outlier(s).
# Column 'NO2_ug/m3' has 22436 outlier(s).
# Column 'NO_ug/m3' has 25830 outlier(s).
# Column 'NOx_ppb' has 22287 outlier(s).
# Column 'Ozone_ug/m3' has 16799 outlier(s).
# Column 'PM10_ug/m3' has 16080 outlier(s).
# Column 'PM2_5_ug/m3' has 18783 outlier(s).
# Column 'RH_%' has 27019 outlier(s).
# Column 'SO2_ug/m3' has 19222 outlier(s).
# Column 'SR_W/mt2' has 43314 outlier(s).
# Column 'Temp_degree_C' has 45681 outlier(s).
# Column 'Toluene_ug/m3' has 27413 outlier(s).
# Column 'WD_deg' has 36583 outlier(s).
# Column 'WS_m/s' has 38176 outlier(s).
# Column 'Xylene_ug/m3' has 1 outlier(s).
# ********************PY********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/PY
# Search pattern: /home/talentum/myproject/dataSource/output/PY/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/PY/part-00000-91211eaf-1127-44db-9db9-fa8c490f150f-c000.csv
# Column 'AT_degree_C' has 379 outlier(s).
# Column 'BP_mmHg' has 13 outlier(s).
# Column 'Benzene_ug/m3' has 886 outlier(s).
# Column 'CO_mg/m3' has 870 outlier(s).
# Column 'NH3_ug/m3' has 840 outlier(s).
# Column 'NO2_ug/m3' has 949 outlier(s).
# Column 'NO_ug/m3' has 1731 outlier(s).
# Column 'NOx_ppb' has 1019 outlier(s).
# Column 'Ozone_ug/m3' has 510 outlier(s).
# Column 'PM10_ug/m3' has 637 outlier(s).
# Column 'PM2_5_ug/m3' has 1097 outlier(s).
# Column 'RF_mm' has 633 outlier(s).
# Column 'RH_%' has 264 outlier(s).
# Column 'SO2_ug/m3' has 1308 outlier(s).
# Column 'SR_W/mt2' has 1970 outlier(s).
# Column 'Temp_degree_C' has 88 outlier(s).
# Column 'Toluene_ug/m3' has 460 outlier(s).
# Column 'WD_degree' has no outliers.
# Column 'WS_m/s' has 107 outlier(s).
# ********************RJ********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/RJ
# Search pattern: /home/talentum/myproject/dataSource/output/RJ/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/RJ/part-00000-7900f211-ae95-4b87-8256-17d55017a202-c000.csv
# Column 'BP_mmHg' has no outliers.
# Column 'Benzene_ug/m3' has 47340 outlier(s).
# Column 'CO_mg/m3' has 26501 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 27861 outlier(s).
# Column 'MP-Xylene_ug/m3' has 30888 outlier(s).
# Column 'NH3_ug/m3' has 32326 outlier(s).
# Column 'NO2_ug/m3' has 37252 outlier(s).
# Column 'NO_ug/m3' has 58038 outlier(s).
# Column 'NOx_ppb' has 37986 outlier(s).
# Column 'O_Xylene_ug/m3' has 31199 outlier(s).
# Column 'Ozone_ug/m3' has 7326 outlier(s).
# Column 'PM10_ug/m3' has 28422 outlier(s).
# Column 'PM2_5_ug/m3' has 23813 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 36043 outlier(s).
# Column 'SR_W/mt2' has no outliers.
# Column 'Temp_degree_C' has 40346 outlier(s).
# Column 'Toluene_ug/m3' has 32886 outlier(s).
# Column 'VWS_m/s' has 51440 outlier(s).
# Column 'WD_deg' has 7951 outlier(s).
# Column 'WS_m/s' has 38379 outlier(s).
# ********************SK********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/SK
# Search pattern: /home/talentum/myproject/dataSource/output/SK/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/SK/part-00000-2c6838c1-b2ff-4b9d-9887-01a22d35ca59-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'Benzene_ug/m3' has 31 outlier(s).
# Column 'CO_mg/m3' has 329 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 366 outlier(s).
# Column 'MP-Xylene_ug/m3' has 267 outlier(s).
# Column 'NH3_ug/m3' has 319 outlier(s).
# Column 'NO2_ug/m3' has 406 outlier(s).
# Column 'NO_ug/m3' has 1053 outlier(s).
# Column 'NOx_ppb' has 380 outlier(s).
# Column 'Ozone_ug/m3' has 815 outlier(s).
# Column 'PM10_ug/m3' has 408 outlier(s).
# Column 'PM2_5_ug/m3' has 580 outlier(s).
# Column 'RF_mm' has 1749 outlier(s).
# Column 'RH_%' has 194 outlier(s).
# Column 'SO2_ug/m3' has 24 outlier(s).
# Column 'SR_W/mt2' has 1430 outlier(s).
# Column 'WD_degree' has no outliers.
# Column 'WS_m/s' has 364 outlier(s).
# ********************TG********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/TG
# Search pattern: /home/talentum/myproject/dataSource/output/TG/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/TG/part-00000-fab4b3a5-bda3-4402-bbaf-1cebc25ab74d-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'BP_mmHg' has 2 outlier(s).
# Column 'Benzene_ug/m3' has 21166 outlier(s).
# Column 'CO_mg/m3' has 9476 outlier(s).
# Column 'NO2_ug/m3' has 31622 outlier(s).
# Column 'NO_ug/m3' has 1090 outlier(s).
# Column 'NOx_ppb' has 10307 outlier(s).
# Column 'Ozone_ug/m3' has 38843 outlier(s).
# Column 'PM2_5_ug/m3' has 3890 outlier(s).
# Column 'RH_%' has 2642 outlier(s).
# Column 'SO2_ug/m3' has 11125 outlier(s).
# Column 'SR_W/mt2' has 58663 outlier(s).
# Column 'Temp_degree_C' has 53530 outlier(s).
# Column 'Toluene_ug/m3' has 26949 outlier(s).
# Column 'VWS_m/s' has 67636 outlier(s).
# Column 'WD_deg' has 37225 outlier(s).
# Column 'WS_m/s' has no outliers.
# Column 'Xylene_ug/m3' has 67277 outlier(s).
# ********************TN********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/TN
# Search pattern: /home/talentum/myproject/dataSource/output/TN/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/TN/part-00000-b526c18c-d2f8-4c53-b202-3dfafd248326-c000.csv
# Column 'BP_mmHg' has no outliers.
# Column 'Benzene_ug/m3' has 29983 outlier(s).
# Column 'CH4_ug/m3' has 166 outlier(s).
# Column 'CO_mg/m3' has 64757 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 14153 outlier(s).
# Column 'MP-Xylene_ug/m3' has no outliers.
# Column 'NH3_ug/m3' has 12111 outlier(s).
# Column 'NO2_ug/m3' has 31995 outlier(s).
# Column 'NO_ug/m3' has 36397 outlier(s).
# Column 'NOx_ppb' has 23965 outlier(s).
# Column 'O_Xylene_ug/m3' has 32 outlier(s).
# Column 'Ozone_ug/m3' has 19023 outlier(s).
# Column 'PM10_ug/m3' has 12111 outlier(s).
# Column 'PM2_5_ug/m3' has 17417 outlier(s).
# Column 'RH_%' has 19226 outlier(s).
# Column 'SO2_ug/m3' has 38695 outlier(s).
# Column 'SR_W/mt2' has 3 outlier(s).
# Column 'THC_ug/m3' has no outliers.
# Column 'Temp_degree_C' has no outliers.
# Column 'Toluene_ug/m3' has 29819 outlier(s).
# Column 'VWS_m/s' has 10735 outlier(s).
# Column 'WD_deg' has 20659 outlier(s).
# Column 'WS_m/s' has 19399 outlier(s).
# ********************TR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/TR
# Search pattern: /home/talentum/myproject/dataSource/output/TR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/TR/part-00000-a554ed9f-6e6a-497a-9234-27319db3732b-c000.csv
# Column 'AT_degree_C' has 24 outlier(s).
# Column 'BP_mmHg' has no outliers.
# Column 'Benzene_ug/m3' has 2687 outlier(s).
# Column 'CO_mg/m3' has 1368 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 527 outlier(s).
# Column 'MP-Xylene_ug/m3' has 761 outlier(s).
# Column 'NH3_ug/m3' has 1761 outlier(s).
# Column 'NO2_ug/m3' has 2534 outlier(s).
# Column 'NO_ug/m3' has 4144 outlier(s).
# Column 'NOx_ppb' has 2953 outlier(s).
# Column 'Ozone_ug/m3' has 3559 outlier(s).
# Column 'PM10_ug/m3' has 1810 outlier(s).
# Column 'PM2_5_ug/m3' has 1083 outlier(s).
# Column 'RF_mm' has 718 outlier(s).
# Column 'RH_%' has 65 outlier(s).
# Column 'SO2_ug/m3' has 4656 outlier(s).
# Column 'SR_W/mt2' has 23 outlier(s).
# Column 'WD_degree' has no outliers.
# Column 'WS_m/s' has no outliers.
# Column 'Xylene_ug/m3' has 1014 outlier(s).
# ********************UK********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/UK
# Search pattern: /home/talentum/myproject/dataSource/output/UK/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/UK/part-00000-be6cde20-35c5-46e7-a987-aa710a6cb326-c000.csv
# Column 'AT_degree' has no outliers.
# Column 'BP_mmHg' has no outliers.
# Column 'CO_mg/m3' has 1739 outlier(s).
# Column 'NO2_ug/m3' has 1537 outlier(s).
# Column 'NO_ug/m3' has 1876 outlier(s).
# Column 'NOx_ppb' has 1105 outlier(s).
# Column 'Ozone_ug/m3' has 401 outlier(s).
# Column 'PM10_ug/m3' has 248 outlier(s).
# Column 'PM2_5_ug/m3' has 432 outlier(s).
# Column 'RH_%' has no outliers.
# Column 'SO2_ug/m3' has 2090 outlier(s).
# Column 'SR_W/mt2' has 1947 outlier(s).
# Column 'WD_degree' has no outliers.
# Column 'WS_m/s' has 484 outlier(s).
# ********************UP********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/UP
# Search pattern: /home/talentum/myproject/dataSource/output/UP/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/UP/part-00000-fbf496b2-25d3-455a-917b-475a86c98eeb-c000.csv
# Column 'AT_degree_C' has no outliers.
# Column 'BP_mmHg' has no outliers.
# Column 'Benzene_ug/m3' has 104822 outlier(s).
# Column 'CO_mg/m3' has 172539 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 58831 outlier(s).
# Column 'MP-Xylene_ug/m3' has 65222 outlier(s).
# Column 'NH3_ug/m3' has 54456 outlier(s).
# Column 'NO2_ug/m3' has 82199 outlier(s).
# Column 'NO_ug/m3' has 172506 outlier(s).
# Column 'NOx_ppb' has 133646 outlier(s).
# Column 'O_Xylene_ug/m3' has 241948 outlier(s).
# Column 'Ozone_ug/m3' has 69022 outlier(s).
# Column 'PM10_ug/m3' has 23299 outlier(s).
# Column 'PM2_5_ug/m3' has 96788 outlier(s).
# Column 'RH_%' has 298530 outlier(s).
# Column 'SO2_ug/m3' has 52628 outlier(s).
# Column 'SR_W/mt2' has 136941 outlier(s).
# Column 'Toluene_ug/m3' has 22077 outlier(s).
# Column 'VWS_m/s' has 129734 outlier(s).
# Column 'WD_deg' has 110139 outlier(s).
# Column 'WS_m/s' has 236791 outlier(s).
# ********************WB********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/WB
# Search pattern: /home/talentum/myproject/dataSource/output/WB/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/WB/part-00000-24211b17-c991-478e-ba05-8783379361fa-c000.csv
# Column 'AT_degree_C' has 1 outlier(s).
# Column 'BP_mmHg' has no outliers.
# Column 'Benzene_ug/m3' has 31203 outlier(s).
# Column 'CO_mg/m3' has 40622 outlier(s).
# Column 'Eth-Benzene_ug/m3' has 38936 outlier(s).
# Column 'MP-Xylene_ug/m3' has 67209 outlier(s).
# Column 'NH3_ug/m3' has 17882 outlier(s).
# Column 'NO2_ug/m3' has 34316 outlier(s).
# Column 'NO_ug/m3' has 61475 outlier(s).
# Column 'NOx_ppb' has 36548 outlier(s).
# Column 'O_Xylene_ug/m3' has 10326 outlier(s).
# Column 'Ozone_ug/m3' has 45056 outlier(s).
# Column 'PM10_ug/m3' has 12673 outlier(s).
# Column 'PM2_5_ug/m3' has 16504 outlier(s).
# Column 'RF_mm' has no outliers.
# Column 'RH_%' has 20119 outlier(s).
# Column 'SO2_ug/m3' has 38677 outlier(s).
# Column 'SR_W/mt2' has no outliers.
# Column 'Temp_' has 28672 outlier(s).
# Column 'Toluene_ug/m3' has 40893 outlier(s).
# Column 'VWS_m/s' has 16 outlier(s).
# Column 'WD_degree' has 32729 outlier(s).
# Column 'WS_m/s' has 4530 outlier(s).

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col
from pyspark.sql.types import DoubleType, IntegerType
import os
import glob

# Initialize Spark session
spark = SparkSession.builder \
    .appName("OutlierDetection") \
    .getOrCreate()

def count_outliers_in_csv(file_path):
    """Count outliers in a given CSV file."""
    # Ensure the file path uses the correct prefix for local files
    if not file_path.startswith('file:///'):
        file_path = 'file://' + file_path

    # Read the CSV file into a DataFrame
    df = spark.read.option("header", "true").csv(file_path, inferSchema=True)

    # Function to identify and count outliers using the IQR method
    def count_outliers(df, column):
        # Calculate Q1 and Q3 using approxQuantile function
        quantiles = df.approxQuantile(column, [0.25, 0.75], 0.05)
        q1, q3 = quantiles
        iqr = q3 - q1
        lower_bound = q1 - 1.5 * iqr
        upper_bound = q3 + 1.5 * iqr

        # Count outliers
        outliers = df.filter((col(column) < lower_bound) | (col(column) > upper_bound))
        outlier_count = outliers.count()

        return outlier_count

    # Dictionary to store the count of outliers for each column
    outlier_counts = {}

    # Apply the outlier counting function to numeric columns only
    for column in df.columns:
        dtype = df.schema[column].dataType
        if isinstance(dtype, (DoubleType, IntegerType)):
            outlier_count = count_outliers(df, column)
            outlier_counts[column] = outlier_count

    # Print the results
    for column, count in outlier_counts.items():
        if count > 0:
            print(f"Column '{column}' has {count} outlier(s).")
        else:
            print(f"Column '{column}' has no outliers.")

    return outlier_counts

def process_csv_files(base_path, state_codes):
    """Process all CSV files for the given state codes."""
    for state_code in state_codes:
        # Construct the directory path
        print("*"*20+f'{state_code}'+"*"*20)
        directory_path = os.path.join(base_path, state_code)
        print(f"Looking for files in directory: {directory_path}")  # Debugging line

        # Construct the search pattern for CSV files
        search_pattern = os.path.join(directory_path, '*.csv')
        print(f"Search pattern: {search_pattern}")  # Debugging line

        # List all CSV files in the directory
        csv_files = glob.glob(search_pattern)

        if not csv_files:
            print(f"No CSV files found in directory: {directory_path}")
            continue

        # Process each CSV file
        for file_path in csv_files:
            print(f"Processing file: {file_path}")
            try:
                outlier_counts = count_outliers_in_csv(file_path)
            except Exception as e:
                print(f"Error processing file {file_path}: {e}")

# Example usage
state_codes = list(state_dict.values()) # Replace with actual state codes
base_path = '/home/talentum/myproject/dataSource/output/Cleaned'  # Local base path

process_csv_files(base_path, state_codes)

# Stop the Spark session
spark.stop()
# Out:
# ********************AP********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/AP
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/AP/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/AP/part-00000-6fb4c158-0a9c-44f2-b760-f08ac2a14898-c000.csv
# Column 'at_degree_c' has 15 outlier(s).
# Column 'bp_mmhg' has 44881 outlier(s).
# Column 'benzene_ug/m3' has 16058 outlier(s).
# Column 'co_mg/m3' has 3871 outlier(s).
# Column 'nh3_ug/m3' has 2842 outlier(s).
# Column 'no2_ug/m3' has 11369 outlier(s).
# Column 'no_ug/m3' has 31573 outlier(s).
# Column 'nox_ppb' has 14169 outlier(s).
# Column 'ozone_ug/m3' has 10806 outlier(s).
# Column 'pm10_ug/m3' has 4379 outlier(s).
# Column 'pm2_5_ug/m3' has 2515 outlier(s).
# Column 'rf_mm' has 25608 outlier(s).
# Column 'rh_%' has no outliers.
# Column 'so2_ug/m3' has 6297 outlier(s).
# Column 'sr_w/mt2' has 9399 outlier(s).
# Column 'temp_degree_c' has 69821 outlier(s).
# Column 'toluene_ug/m3' has 16899 outlier(s).
# Column 'vws_m/s' has 34753 outlier(s).
# Column 'wd_deg' has 710 outlier(s).
# Column 'ws_m/s' has 6 outlier(s).
# Column 'xylene_ug/m3' has no outliers.
# ********************AR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/AR
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/AR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/AR/part-00000-b4807cdd-5a30-4537-8c32-5636363d77be-c000.csv
# Column 'at_degree_c' has 7 outlier(s).
# Column 'bp_mmhg' has 3 outlier(s).
# Column 'benzene_ug/m3' has 315 outlier(s).
# Column 'co_mg/m3' has 786 outlier(s).
# Column 'eth-benzene_ug/m3' has 3277 outlier(s).
# Column 'mp-xylene_ug/m3' has 3666 outlier(s).
# Column 'nh3_ug/m3' has 336 outlier(s).
# Column 'no2_ug/m3' has 112 outlier(s).
# Column 'no_ug/m3' has 708 outlier(s).
# Column 'nox_ppb' has 65 outlier(s).
# Column 'ozone_ug/m3' has 54 outlier(s).
# Column 'pm10_ug/m3' has 594 outlier(s).
# Column 'pm2_5_ug/m3' has 352 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 1 outlier(s).
# Column 'so2_ug/m3' has no outliers.
# Column 'sr_w/mt2' has 3794 outlier(s).
# Column 'wd_degree' has 18 outlier(s).
# Column 'ws_m/s' has 253 outlier(s).
# ********************AS********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/AS
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/AS/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/AS/part-00000-a978995a-1bd1-4471-8862-1c3af66cfc6b-c000.csv
# Column 'at_degree_c' has 11160 outlier(s).
# Column 'bp_mmhg' has 28112 outlier(s).
# Column 'benzene_ug/m3' has 6127 outlier(s).
# Column 'co_mg/m3' has 4298 outlier(s).
# Column 'eth-benzene_ug/m3' has 29219 outlier(s).
# Column 'mp-xylene_ug/m3' has 36298 outlier(s).
# Column 'nh3_ug/m3' has 2528 outlier(s).
# Column 'no2_ug/m3' has 3516 outlier(s).
# Column 'no_ug/m3' has 3036 outlier(s).
# Column 'nox_ppb' has 8085 outlier(s).
# Column 'ozone_ug/m3' has 6256 outlier(s).
# Column 'pm10_ug/m3' has 3537 outlier(s).
# Column 'pm2_5_ug/m3' has 3885 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 12876 outlier(s).
# Column 'so2_ug/m3' has 1787 outlier(s).
# Column 'sr_w/mt2' has 5578 outlier(s).
# Column 'wd_degree' has 183 outlier(s).
# Column 'ws_m/s' has 4164 outlier(s).
# ********************BR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/BR
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/BR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/BR/part-00000-4e09487b-138e-4a72-96aa-f0f95d6f7611-c000.csv
# Column 'at_degree_c' has no outliers.
# Column 'bp_mmhg' has no outliers.
# Column 'benzene_ug/m3' has 25258 outlier(s).
# Column 'co_mg/m3' has 16990 outlier(s).
# Column 'no2_ug/m3' has 96952 outlier(s).
# Column 'no_ug/m3' has 26572 outlier(s).
# Column 'nox_ppb' has 15153 outlier(s).
# Column 'ozone_ug/m3' has 35522 outlier(s).
# Column 'pm2_5_ug/m3' has 16197 outlier(s).
# Column 'rh_%' has 93587 outlier(s).
# Column 'so2_ug/m3' has 20628 outlier(s).
# Column 'sr_w/mt2' has 240239 outlier(s).
# Column 'temp_' has 120051 outlier(s).
# Column 'toluene_ug/m3' has 16401 outlier(s).
# Column 'vws_m/s' has 113547 outlier(s).
# Column 'wd_deg' has 82229 outlier(s).
# Column 'ws_m/s' has 38476 outlier(s).
# Column 'xylene_ug/m3' has no outliers.
# ********************CG********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/CG
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/CG/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/CG/part-00000-fced351a-2c15-4360-8ec3-f34271131469-c000.csv
# Column 'at_degree_c' has 2063 outlier(s).
# Column 'bp_mmhg' has 12905 outlier(s).
# Column 'co_mg/m3' has 3352 outlier(s).
# Column 'no2_ug/m3' has 9640 outlier(s).
# Column 'no_ug/m3' has 14298 outlier(s).
# Column 'nox_ppb' has 12910 outlier(s).
# Column 'pm10_ug/m3' has 9086 outlier(s).
# Column 'pm2_5_ug/m3' has 8482 outlier(s).
# Column 'rf_mm' has 13323 outlier(s).
# Column 'rh_%' has 9670 outlier(s).
# Column 'so2_ug/m3' has 10007 outlier(s).
# Column 'sr_w/mt2' has 6617 outlier(s).
# Column 'wd_degree' has 10960 outlier(s).
# Column 'ws_m/s' has 8288 outlier(s).
# ********************CH********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/CH
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/CH/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/CH/part-00000-50e4b254-70c9-4140-a234-857e1255cc13-c000.csv
# Column 'at_degree_c' has no outliers.
# Column 'bp_mmhg' has 19350 outlier(s).
# Column 'benzene_ug/m3' has 1526 outlier(s).
# Column 'co_mg/m3' has 2056 outlier(s).
# Column 'eth-benzene_ug/m3' has 3673 outlier(s).
# Column 'mp-xylene_ug/m3' has 6224 outlier(s).
# Column 'nh3_ug/m3' has 3823 outlier(s).
# Column 'no2_ug/m3' has 4090 outlier(s).
# Column 'no_ug/m3' has 8511 outlier(s).
# Column 'nox_ppb' has 5475 outlier(s).
# Column 'ozone_ug/m3' has 2302 outlier(s).
# Column 'pm10_ug/m3' has 1281 outlier(s).
# Column 'pm2_5_ug/m3' has 1858 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 10745 outlier(s).
# Column 'so2_ug/m3' has 2338 outlier(s).
# Column 'sr_w/mt2' has 837 outlier(s).
# Column 'toluene_ug/m3' has 6726 outlier(s).
# Column 'vws_m/s' has 21107 outlier(s).
# Column 'wd_degree' has no outliers.
# Column 'ws_m/s' has no outliers.
# Column 'xylene_ug/m3' has 9424 outlier(s).
# ********************DL********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/DL
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/DL/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/DL/part-00000-d80fc397-188e-4714-b915-2761156085d1-c000.csv
# Column 'bp_mmhg' has 263633 outlier(s).
# Column 'benzene_ug/m3' has 239065 outlier(s).
# Column 'co_mg/m3' has 125903 outlier(s).
# Column 'mp-xylene_ug/m3' has 780006 outlier(s).
# Column 'nh3_ug/m3' has 116598 outlier(s).
# Column 'no2_ug/m3' has no outliers.
# Column 'no_ug/m3' has 201430 outlier(s).
# Column 'nox_ppb' has 116130 outlier(s).
# Column 'o_xylene_ug/m3' has 706796 outlier(s).
# Column 'ozone_ug/m3' has 148385 outlier(s).
# Column 'pm10_ug/m3' has 75700 outlier(s).
# Column 'pm2_5_ug/m3' has 63547 outlier(s).
# Column 'rh_%' has 103797 outlier(s).
# Column 'so2_ug/m3' has 44845 outlier(s).
# Column 'sr_w/mt2' has 461228 outlier(s).
# Column 'temp_degree_c' has 51 outlier(s).
# Column 'toluene_ug/m3' has 647720 outlier(s).
# Column 'wd_deg' has 329520 outlier(s).
# Column 'ws_m/s' has 595473 outlier(s).
# ********************GJ********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/GJ
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/GJ/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/GJ/part-00000-54108913-5eb2-4879-bb68-b482acc5959d-c000.csv
# Column 'at_degree_c' has 112071 outlier(s).
# Column 'bp_mmhg' has 162448 outlier(s).
# Column 'benzene_ug/m3' has 30474 outlier(s).
# Column 'co_mg/m3' has 11435 outlier(s).
# Column 'eth-benzene_ug/m3' has 138453 outlier(s).
# Column 'mp-xylene_ug/m3' has 129189 outlier(s).
# Column 'no2_ug/m3' has 38034 outlier(s).
# Column 'no_ug/m3' has 34556 outlier(s).
# Column 'nox_ppb' has 68784 outlier(s).
# Column 'ozone_ug/m3' has 34870 outlier(s).
# Column 'pm10_ug/m3' has 19448 outlier(s).
# Column 'pm2_5_ug/m3' has 25035 outlier(s).
# Column 'rh_%' has 97246 outlier(s).
# Column 'so2_ug/m3' has 19104 outlier(s).
# Column 'sr_w/mt2' has 10432 outlier(s).
# Column 'toluene_ug/m3' has 51025 outlier(s).
# Column 'wd_deg' has no outliers.
# Column 'ws_m/s' has no outliers.
# Column 'xylene_ug/m3' has 24092 outlier(s).
# ********************HP********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/HP
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/HP/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/HP/part-00000-00314183-2c55-4706-b272-fab066c7e72e-c000.csv
# Column 'at_degree_c' has 138 outlier(s).
# Column 'benzene_ug/m3' has 1356 outlier(s).
# Column 'co_mg/m3' has 418 outlier(s).
# Column 'eth-benzene_ug/m3' has 2710 outlier(s).
# Column 'mp-xylene_ug/m3' has 3395 outlier(s).
# Column 'nh3_ug/m3' has 428 outlier(s).
# Column 'no2_ug/m3' has 395 outlier(s).
# Column 'no_ug/m3' has 1235 outlier(s).
# Column 'nox_ppb' has 420 outlier(s).
# Column 'o_xylene_ug/m3' has 3013 outlier(s).
# Column 'ozone_ug/m3' has 235 outlier(s).
# Column 'pm10_ug/m3' has 253 outlier(s).
# Column 'pm2_5_ug/m3' has 537 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 12 outlier(s).
# Column 'so2_ug/m3' has 857 outlier(s).
# Column 'sr_w/mt2' has 248 outlier(s).
# Column 'toluene_ug/m3' has 1221 outlier(s).
# Column 'wd_degree' has no outliers.
# Column 'ws_m/s' has 291 outlier(s).
# ********************HR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/HR
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/HR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/HR/part-00000-09e3ceea-b772-44ac-b90c-a9469429c58d-c000.csv
# Column 'at_degree_c' has 393200 outlier(s).
# Column 'bp_mmhg' has 253344 outlier(s).
# Column 'benzene_ug/m3' has 76616 outlier(s).
# Column 'co_mg/m3' has 11293 outlier(s).
# Column 'no2_ug/m3' has 57832 outlier(s).
# Column 'no_ug/m3' has 26193 outlier(s).
# Column 'nox_ppb' has 38116 outlier(s).
# Column 'ozone_ug/m3' has 50333 outlier(s).
# Column 'pm2_5_ug/m3' has 24484 outlier(s).
# Column 'rf_mm' has 55084 outlier(s).
# Column 'rh_%' has 177413 outlier(s).
# Column 'so2_ug/m3' has 11104 outlier(s).
# Column 'sr_w/mt2' has 5295 outlier(s).
# Column 'temp_degree_c' has 136859 outlier(s).
# Column 'toluene_ug/m3' has 28826 outlier(s).
# Column 'vws_m/s' has no outliers.
# Column 'wd_deg' has 91556 outlier(s).
# Column 'ws_m/s' has 89636 outlier(s).
# Column 'xylene_ug/m3' has 406596 outlier(s).
# ********************JH********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/JH
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/JH/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/JH/part-00000-f366e1ed-f957-4819-beff-b8423fcd81ec-c000.csv
# Column 'nh3_ug/m3' has 16674 outlier(s).
# Column 'no2_ug/m3' has 22776 outlier(s).
# Column 'no_ug/m3' has 19749 outlier(s).
# Column 'ozone_ug/m3' has 24281 outlier(s).
# Column 'pm10_ug/m3' has 24475 outlier(s).
# Column 'so2_ug/m3' has 21467 outlier(s).
# Column 'temp_degree_c' has 23192 outlier(s).
# Column 'vws_m/s' has 22338 outlier(s).
# ********************JK********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/JK
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/JK/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/JK/part-00000-dd32e663-6312-4a7d-bffe-8c79c9c23bbd-c000.csv
# Column 'co_mg/m3' has 2972 outlier(s).
# Column 'nh3_ug/m3' has 2631 outlier(s).
# Column 'no2_ug/m3' has 1786 outlier(s).
# Column 'no_ug/m3' has 3924 outlier(s).
# Column 'nox_ppb' has 744 outlier(s).
# Column 'ozone_ug/m3' has 4134 outlier(s).
# Column 'pm10_ug/m3' has 1187 outlier(s).
# Column 'pm2_5_ug/m3' has 1023 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 15 outlier(s).
# Column 'so2_ug/m3' has 1321 outlier(s).
# Column 'sr_w/mt2' has 3264 outlier(s).
# Column 'temp_degree_c' has 77 outlier(s).
# Column 'toluene_ug/m3' has 18 outlier(s).
# Column 'wd_degree' has 52 outlier(s).
# Column 'ws_m/s' has 465 outlier(s).
# ********************KA********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/KA
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/KA/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/KA/part-00000-71970b3f-5fa9-4a8b-b8d9-efe03cd01180-c000.csv
# Column 'benzene_ug/m3' has 417499 outlier(s).
# Column 'co_mg/m3' has 41045 outlier(s).
# Column 'nh3_ug/m3' has 37769 outlier(s).
# Column 'no2_ug/m3' has 18853 outlier(s).
# Column 'no_ug/m3' has 127700 outlier(s).
# Column 'nox_ppb' has 27788 outlier(s).
# Column 'o_xylene_ug/m3' has 445264 outlier(s).
# Column 'ozone_ug/m3' has 56720 outlier(s).
# Column 'pm10_ug/m3' has 56557 outlier(s).
# Column 'pm2_5_ug/m3' has 43204 outlier(s).
# Column 'rh_%' has 47707 outlier(s).
# Column 'so2_ug/m3' has 99444 outlier(s).
# Column 'temp_degree_c' has 304575 outlier(s).
# Column 'toluene_ug/m3' has 412672 outlier(s).
# Column 'wd_deg' has 83 outlier(s).
# Column 'ws_m/s' has 164097 outlier(s).
# ********************KL********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/KL
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/KL/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/KL/part-00000-2d319a52-782c-4e9b-a321-070a752287c5-c000.csv
# Column 'at_degree_c' has 82778 outlier(s).
# Column 'bp_mmhg' has 50962 outlier(s).
# Column 'co_mg/m3' has 3699 outlier(s).
# Column 'nh3_ug/m3' has 8554 outlier(s).
# Column 'no2_ug/m3' has 11662 outlier(s).
# Column 'no_ug/m3' has 39003 outlier(s).
# Column 'nox_ppb' has 8141 outlier(s).
# Column 'ozone_ug/m3' has 8671 outlier(s).
# Column 'pm10_ug/m3' has 7844 outlier(s).
# Column 'pm2_5_ug/m3' has 12418 outlier(s).
# Column 'rf_mm' has 50743 outlier(s).
# Column 'rh_%' has 36791 outlier(s).
# Column 'so2_ug/m3' has 15221 outlier(s).
# Column 'sr_w/mt2' has 2468 outlier(s).
# Column 'temp_degree_c' has 67431 outlier(s).
# Column 'wd_deg' has 134141 outlier(s).
# Column 'ws_m/s' has 117038 outlier(s).
# ********************MH********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/MH
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/MH/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/MH/part-00000-2501e072-30a8-432a-b896-4b72134b56d7-c000.csv
# Column 'bp_mmhg' has 436062 outlier(s).
# Column 'benzene_ug/m3' has 64368 outlier(s).
# Column 'co_mg/m3' has 126911 outlier(s).
# Column 'mp-xylene_ug/m3' has 473202 outlier(s).
# Column 'no2_ug/m3' has 143052 outlier(s).
# Column 'no_ug/m3' has 116386 outlier(s).
# Column 'nox_ppb' has 58378 outlier(s).
# Column 'ozone_ug/m3' has 88535 outlier(s).
# Column 'pm10_ug/m3' has 41211 outlier(s).
# Column 'pm2_5_ug/m3' has 167651 outlier(s).
# Column 'rh_%' has 193552 outlier(s).
# Column 'so2_ug/m3' has 72194 outlier(s).
# Column 'sr_w/mt2' has 57278 outlier(s).
# Column 'temp_degree_c' has 462146 outlier(s).
# Column 'toluene_ug/m3' has 138761 outlier(s).
# Column 'vws_m/s' has 531818 outlier(s).
# Column 'wd_deg' has 153554 outlier(s).
# Column 'ws_m/s' has 127166 outlier(s).
# ********************ML********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/ML
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/ML/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/ML/part-00000-435ae8d7-ca32-4eee-8bab-e4a2d0119074-c000.csv
# Column 'at_degree_c' has 11264 outlier(s).
# Column 'benzene_ug/m3' has 6985 outlier(s).
# Column 'co_mg/m3' has 637 outlier(s).
# Column 'nh3_ug/m3' has 68 outlier(s).
# Column 'no2_ug/m3' has 6824 outlier(s).
# Column 'no_ug/m3' has 6287 outlier(s).
# Column 'nox_ppb' has 43 outlier(s).
# Column 'ozone_ug/m3' has 2202 outlier(s).
# Column 'pm10_ug/m3' has 3944 outlier(s).
# Column 'pm2_5_ug/m3' has 4036 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 136 outlier(s).
# Column 'so2_ug/m3' has 878 outlier(s).
# Column 'sr_w/mt2' has 10840 outlier(s).
# Column 'toluene_ug/m3' has 5737 outlier(s).
# Column 'wd_degree' has 2212 outlier(s).
# Column 'ws_m/s' has 3037 outlier(s).
# ********************MN********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/MN
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/MN/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/MN/part-00000-d6dcf352-3bdb-4cea-85af-99b6756625e4-c000.csv
# Column 'at_degree_c' has 371 outlier(s).
# Column 'benzene_ug/m3' has 3023 outlier(s).
# Column 'co_mg/m3' has 2918 outlier(s).
# Column 'eth-benzene_ug/m3' has 2485 outlier(s).
# Column 'mp-xylene_ug/m3' has 6531 outlier(s).
# Column 'nh3_ug/m3' has 5833 outlier(s).
# Column 'no2_ug/m3' has 3236 outlier(s).
# Column 'no_ug/m3' has 1336 outlier(s).
# Column 'nox_ppb' has 3376 outlier(s).
# Column 'ozone_ug/m3' has 6026 outlier(s).
# Column 'pm10_ug/m3' has 1441 outlier(s).
# Column 'pm2_5_ug/m3' has 1607 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has no outliers.
# Column 'so2_ug/m3' has 1 outlier(s).
# Column 'sr_w/mt2' has 2677 outlier(s).
# Column 'wd_degree' has 212 outlier(s).
# Column 'ws_m/s' has 884 outlier(s).
# ********************MP********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/MP
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/MP/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/MP/part-00000-f3a892b0-9dd2-4b4a-9e20-1bac5473329e-c000.csv
# Column 'benzene_ug/m3' has 205738 outlier(s).
# Column 'co_mg/m3' has 43109 outlier(s).
# Column 'eth-benzene_ug/m3' has 201813 outlier(s).
# Column 'nh3_ug/m3' has 14185 outlier(s).
# Column 'no2_ug/m3' has 64942 outlier(s).
# Column 'no_ug/m3' has 34875 outlier(s).
# Column 'nox_ppb' has 8435 outlier(s).
# Column 'ozone_ug/m3' has 219193 outlier(s).
# Column 'pm10_ug/m3' has 32123 outlier(s).
# Column 'pm2_5_ug/m3' has 44630 outlier(s).
# Column 'rh_%' has 80195 outlier(s).
# Column 'so2_ug/m3' has 13191 outlier(s).
# Column 'temp_degree_c' has 207550 outlier(s).
# Column 'toluene_ug/m3' has 225042 outlier(s).
# Column 'wd_deg' has 238281 outlier(s).
# Column 'ws_m/s' has 221499 outlier(s).
# ********************MZ********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/MZ
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/MZ/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/MZ/part-00000-159bcf33-a6b7-42e1-a065-f940bee1a8d2-c000.csv
# Column 'bp_mmhg' has 12220 outlier(s).
# Column 'benzene_ug/m3' has 1141 outlier(s).
# Column 'co_mg/m3' has 195 outlier(s).
# Column 'eth-benzene_ug/m3' has 10281 outlier(s).
# Column 'mp-xylene_ug/m3' has 11828 outlier(s).
# Column 'nh3_ug/m3' has 1471 outlier(s).
# Column 'no2_ug/m3' has 3012 outlier(s).
# Column 'no_ug/m3' has no outliers.
# Column 'nox_ppb' has 4 outlier(s).
# Column 'ozone_ug/m3' has 2868 outlier(s).
# Column 'pm10_ug/m3' has 2239 outlier(s).
# Column 'pm2_5_ug/m3' has 4650 outlier(s).
# Column 'rh_%' has 13119 outlier(s).
# Column 'so2_ug/m3' has no outliers.
# Column 'wd_degree' has 12808 outlier(s).
# Column 'ws_m/s' has 12592 outlier(s).
# ********************NL********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/NL
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/NL/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/NL/part-00000-78fd914b-695c-41b6-aa3c-d95e4a46a566-c000.csv
# Column 'at_degree_c' has 3815 outlier(s).
# Column 'bp_mmhg' has 2325 outlier(s).
# Column 'benzene_ug/m3' has 1732 outlier(s).
# Column 'co_mg/m3' has 1020 outlier(s).
# Column 'eth-benzene_ug/m3' has 9997 outlier(s).
# Column 'mp-xylene_ug/m3' has 10972 outlier(s).
# Column 'nh3_ug/m3' has 1902 outlier(s).
# Column 'no2_ug/m3' has 557 outlier(s).
# Column 'no_ug/m3' has 375 outlier(s).
# Column 'nox_ppb' has 614 outlier(s).
# Column 'ozone_ug/m3' has 1377 outlier(s).
# Column 'pm10_ug/m3' has 1179 outlier(s).
# Column 'pm2_5_ug/m3' has 1582 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 3316 outlier(s).
# Column 'so2_ug/m3' has 65 outlier(s).
# Column 'wd_degree' has 32 outlier(s).
# Column 'ws_m/s' has 2268 outlier(s).
# ********************OR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/OR
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/OR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/OR/part-00000-10f70b0f-da9e-40e9-bad0-10ed5f8f5b4b-c000.csv
# Column 'at_degree_c' has 38953 outlier(s).
# Column 'benzene_ug/m3' has 21649 outlier(s).
# Column 'co_mg/m3' has 1336 outlier(s).
# Column 'eth-benzene_ug/m3' has 2339 outlier(s).
# Column 'mp-xylene_ug/m3' has 123 outlier(s).
# Column 'nh3_ug/m3' has 3956 outlier(s).
# Column 'no2_ug/m3' has 9546 outlier(s).
# Column 'no_ug/m3' has 8320 outlier(s).
# Column 'nox_ug/m3' has 4827 outlier(s).
# Column 'ozone_ug/m3' has 11013 outlier(s).
# Column 'pm10_ug/m3' has 5038 outlier(s).
# Column 'pm2_5_ug/m3' has 3042 outlier(s).
# Column 'rh_degree' has 45380 outlier(s).
# Column 'so2_ug/m3' has 6832 outlier(s).
# Column 'toluene_ug/m3' has 46265 outlier(s).
# Column 'wd_degree' has 39398 outlier(s).
# Column 'ws_m/s' has 41132 outlier(s).
# ********************PB********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/PB
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/PB/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/PB/part-00000-e8680dfb-4146-4858-86f5-bb9cc72f88a4-c000.csv
# Column 'benzene_ug/m3' has 81377 outlier(s).
# Column 'co_mg/m3' has 41038 outlier(s).
# Column 'nh3_ug/m3' has 40689 outlier(s).
# Column 'no2_ug/m3' has 15639 outlier(s).
# Column 'no_ug/m3' has 11332 outlier(s).
# Column 'nox_ppb' has 9094 outlier(s).
# Column 'ozone_ug/m3' has 17896 outlier(s).
# Column 'pm10_ug/m3' has 5428 outlier(s).
# Column 'pm2_5_ug/m3' has 7331 outlier(s).
# Column 'rh_%' has 198564 outlier(s).
# Column 'so2_ug/m3' has 12783 outlier(s).
# Column 'sr_w/mt2' has 192530 outlier(s).
# Column 'temp_degree_c' has 88993 outlier(s).
# Column 'toluene_ug/m3' has 133852 outlier(s).
# Column 'wd_deg' has 40523 outlier(s).
# Column 'ws_m/s' has 166516 outlier(s).
# Column 'xylene_ug/m3' has 99115 outlier(s).
# ********************PY********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/PY
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/PY/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/PY/part-00000-1eef3366-ef63-42a6-add3-0ed082d5702b-c000.csv
# Column 'at_degree_c' has 343 outlier(s).
# Column 'bp_mmhg' has no outliers.
# Column 'benzene_ug/m3' has 733 outlier(s).
# Column 'co_mg/m3' has 717 outlier(s).
# Column 'nh3_ug/m3' has 496 outlier(s).
# Column 'no2_ug/m3' has 651 outlier(s).
# Column 'no_ug/m3' has 1681 outlier(s).
# Column 'nox_ppb' has 674 outlier(s).
# Column 'ozone_ug/m3' has 372 outlier(s).
# Column 'pm10_ug/m3' has 451 outlier(s).
# Column 'pm2_5_ug/m3' has 1131 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 176 outlier(s).
# Column 'so2_ug/m3' has 1001 outlier(s).
# Column 'sr_w/mt2' has 2650 outlier(s).
# Column 'temp_degree_c' has 38 outlier(s).
# Column 'toluene_ug/m3' has 1535 outlier(s).
# Column 'wd_degree' has no outliers.
# Column 'ws_m/s' has 98 outlier(s).
# ********************RJ********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/RJ
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/RJ/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/RJ/part-00000-b8fb8fe8-2e6a-45fd-b595-b819311720cf-c000.csv
# Column 'bp_mmhg' has no outliers.
# Column 'benzene_ug/m3' has 19202 outlier(s).
# Column 'co_mg/m3' has 7620 outlier(s).
# Column 'eth-benzene_ug/m3' has 49385 outlier(s).
# Column 'mp-xylene_ug/m3' has 171100 outlier(s).
# Column 'nh3_ug/m3' has 20698 outlier(s).
# Column 'no2_ug/m3' has 11345 outlier(s).
# Column 'no_ug/m3' has 23565 outlier(s).
# Column 'nox_ppb' has 19580 outlier(s).
# Column 'o_xylene_ug/m3' has 184833 outlier(s).
# Column 'ozone_ug/m3' has no outliers.
# Column 'pm10_ug/m3' has 8041 outlier(s).
# Column 'pm2_5_ug/m3' has 7563 outlier(s).
# Column 'rh_%' has no outliers.
# Column 'so2_ug/m3' has 10281 outlier(s).
# Column 'sr_w/mt2' has no outliers.
# Column 'temp_degree_c' has 48195 outlier(s).
# Column 'toluene_ug/m3' has 164110 outlier(s).
# Column 'vws_m/s' has no outliers.
# Column 'wd_deg' has 1571 outlier(s).
# Column 'ws_m/s' has 91356 outlier(s).
# ********************SK********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/SK
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/SK/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/SK/part-00000-dbcfecac-9389-42a6-b5de-66c754a3dc25-c000.csv
# Column 'at_degree_c' has 23 outlier(s).
# Column 'benzene_ug/m3' has no outliers.
# Column 'co_mg/m3' has 224 outlier(s).
# Column 'eth-benzene_ug/m3' has 210 outlier(s).
# Column 'mp-xylene_ug/m3' has 287 outlier(s).
# Column 'nh3_ug/m3' has 419 outlier(s).
# Column 'no2_ug/m3' has 497 outlier(s).
# Column 'no_ug/m3' has 1061 outlier(s).
# Column 'nox_ppb' has 223 outlier(s).
# Column 'ozone_ug/m3' has 762 outlier(s).
# Column 'pm10_ug/m3' has 1562 outlier(s).
# Column 'pm2_5_ug/m3' has 1427 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 492 outlier(s).
# Column 'so2_ug/m3' has 22 outlier(s).
# Column 'sr_w/mt2' has 2116 outlier(s).
# Column 'wd_degree' has 10 outlier(s).
# Column 'ws_m/s' has 445 outlier(s).
# ********************TG********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/TG
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/TG/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/TG/part-00000-b86edebf-65a9-4ce6-8762-44ec93e4334c-c000.csv
# Column 'at_degree_c' has no outliers.
# Column 'bp_mmhg' has 80688 outlier(s).
# Column 'benzene_ug/m3' has 5166 outlier(s).
# Column 'co_mg/m3' has 2353 outlier(s).
# Column 'no2_ug/m3' has 22212 outlier(s).
# Column 'no_ug/m3' has no outliers.
# Column 'nox_ppb' has 3346 outlier(s).
# Column 'ozone_ug/m3' has 44654 outlier(s).
# Column 'pm2_5_ug/m3' has 411 outlier(s).
# Column 'rh_%' has 84712 outlier(s).
# Column 'so2_ug/m3' has 6619 outlier(s).
# Column 'sr_w/mt2' has 23743 outlier(s).
# Column 'temp_degree_c' has 28408 outlier(s).
# Column 'toluene_ug/m3' has 29836 outlier(s).
# Column 'vws_m/s' has 38633 outlier(s).
# Column 'wd_deg' has 8622 outlier(s).
# Column 'ws_m/s' has no outliers.
# Column 'xylene_ug/m3' has 108522 outlier(s).
# ********************TN********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/TN
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/TN/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/TN/part-00000-9ddadb18-76d2-496e-ae50-f8e6ceaa551c-c000.csv
# Column 'bp_mmhg' has 94155 outlier(s).
# Column 'benzene_ug/m3' has 251554 outlier(s).
# Column 'co_mg/m3' has 117151 outlier(s).
# Column 'nh3_ug/m3' has 161350 outlier(s).
# Column 'no2_ug/m3' has 14348 outlier(s).
# Column 'no_ug/m3' has 38819 outlier(s).
# Column 'nox_ppb' has 36759 outlier(s).
# Column 'o_xylene_ug/m3' has 211671 outlier(s).
# Column 'ozone_ug/m3' has 82892 outlier(s).
# Column 'pm10_ug/m3' has 221505 outlier(s).
# Column 'pm2_5_ug/m3' has 29234 outlier(s).
# Column 'rh_%' has 27045 outlier(s).
# Column 'so2_ug/m3' has 44703 outlier(s).
# Column 'sr_w/mt2' has 39039 outlier(s).
# Column 'temp_degree_c' has 162888 outlier(s).
# Column 'toluene_ug/m3' has 82654 outlier(s).
# Column 'vws_m/s' has 129954 outlier(s).
# Column 'wd_deg' has 14489 outlier(s).
# Column 'ws_m/s' has 29293 outlier(s).
# ********************TR********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/TR
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/TR/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/TR/part-00000-9cc7a078-b104-453a-be92-9b77ec9c3e1e-c000.csv
# Column 'at_degree_c' has 14828 outlier(s).
# Column 'bp_mmhg' has no outliers.
# Column 'benzene_ug/m3' has 3793 outlier(s).
# Column 'co_mg/m3' has 1148 outlier(s).
# Column 'mp-xylene_ug/m3' has 11781 outlier(s).
# Column 'nh3_ug/m3' has 1758 outlier(s).
# Column 'no2_ug/m3' has 2338 outlier(s).
# Column 'no_ug/m3' has 3049 outlier(s).
# Column 'nox_ppb' has 2826 outlier(s).
# Column 'ozone_ug/m3' has 3163 outlier(s).
# Column 'pm10_ug/m3' has 2071 outlier(s).
# Column 'pm2_5_ug/m3' has 1525 outlier(s).
# Column 'rf_mm' has no outliers.
# Column 'rh_%' has 14789 outlier(s).
# Column 'so2_ug/m3' has 3584 outlier(s).
# Column 'sr_w/mt2' has 2528 outlier(s).
# Column 'wd_degree' has 1148 outlier(s).
# Column 'ws_m/s' has 6649 outlier(s).
# ********************UK********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/UK
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/UK/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/UK/part-00000-be649329-6368-470b-b57a-8b22d46ce8fe-c000.csv
# Column 'at_degree' has 2381 outlier(s).
# Column 'bp_mmhg' has 2887 outlier(s).
# Column 'co_mg/m3' has 3185 outlier(s).
# Column 'no2_ug/m3' has 3512 outlier(s).
# Column 'no_ug/m3' has 2915 outlier(s).
# Column 'nox_ppb' has 2340 outlier(s).
# Column 'ozone_ug/m3' has 1465 outlier(s).
# Column 'pm10_ug/m3' has 1132 outlier(s).
# Column 'pm2_5_ug/m3' has 1671 outlier(s).
# Column 'rh_%' has 5 outlier(s).
# Column 'so2_ug/m3' has 3964 outlier(s).
# Column 'sr_w/mt2' has 1735 outlier(s).
# Column 'wd_degree' has 2734 outlier(s).
# Column 'ws_m/s' has 1378 outlier(s).
# ********************UP********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/UP
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/UP/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/UP/part-00000-0f8d0b16-d530-4b20-b4cf-5e8a9d5791bb-c000.csv
# Column 'at_degree_c' has 652982 outlier(s).
# Column 'bp_mmhg' has 498549 outlier(s).
# Column 'benzene_ug/m3' has 167458 outlier(s).
# Column 'co_mg/m3' has 143114 outlier(s).
# Column 'eth-benzene_ug/m3' has 665143 outlier(s).
# Column 'mp-xylene_ug/m3' has 669018 outlier(s).
# Column 'nh3_ug/m3' has 80849 outlier(s).
# Column 'no2_ug/m3' has 44494 outlier(s).
# Column 'no_ug/m3' has 92275 outlier(s).
# Column 'nox_ppb' has 63695 outlier(s).
# Column 'o_xylene_ug/m3' has 618756 outlier(s).
# Column 'ozone_ug/m3' has 92926 outlier(s).
# Column 'pm10_ug/m3' has 109752 outlier(s).
# Column 'pm2_5_ug/m3' has 81491 outlier(s).
# Column 'rh_%' has 298263 outlier(s).
# Column 'so2_ug/m3' has 121667 outlier(s).
# Column 'sr_w/mt2' has 251705 outlier(s).
# Column 'toluene_ug/m3' has 106108 outlier(s).
# Column 'wd_deg' has 480 outlier(s).
# Column 'ws_m/s' has 244075 outlier(s).
# ********************WB********************
# Looking for files in directory: /home/talentum/myproject/dataSource/output/Cleaned/WB
# Search pattern: /home/talentum/myproject/dataSource/output/Cleaned/WB/*.csv
# Processing file: /home/talentum/myproject/dataSource/output/Cleaned/WB/part-00000-475e9e84-83da-4208-b793-45c56ef8b8a5-c000.csv
# Column 'bp_mmhg' has 248850 outlier(s).
# Column 'benzene_ug/m3' has 46445 outlier(s).
# Column 'co_mg/m3' has 14386 outlier(s).
# Column 'eth-benzene_ug/m3' has 201703 outlier(s).
# Column 'mp-xylene_ug/m3' has 68105 outlier(s).
# Column 'nh3_ug/m3' has 49345 outlier(s).
# Column 'no2_ug/m3' has 19078 outlier(s).
# Column 'no_ug/m3' has 23592 outlier(s).
# Column 'nox_ppb' has 23246 outlier(s).
# Column 'o_xylene_ug/m3' has 240664 outlier(s).
# Column 'ozone_ug/m3' has 17718 outlier(s).
# Column 'pm10_ug/m3' has 767 outlier(s).
# Column 'pm2_5_ug/m3' has 15605 outlier(s).
# Column 'rh_%' has 3185 outlier(s).
# Column 'so2_ug/m3' has 9438 outlier(s).
# Column 'sr_w/mt2' has 96032 outlier(s).
# Column 'temp_' has 101654 outlier(s).
# Column 'toluene_ug/m3' has 74727 outlier(s).
# Column 'vws_m/s' has 195056 outlier(s).
# Column 'wd_degree' has 9920 outlier(s).
# Column 'ws_m/s' has 83158 outlier(s).

# %%
***************************************2*******************************************

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit

# Initialize a Spark session
spark = SparkSession.builder.appName("CSV Merge").getOrCreate()

# List of state codes (assuming state_dict is defined elsewhere in your code)
state_codes = list(state_dict.values())

# Read the CSV files into a list of DataFrames
dfs = []
print("Starting to read CSV files...")
for state_code in state_codes:
    file_path = f"file:///home/talentum/myproject/dataSource/output/Cleaned/{state_code}/*.csv"
    print(f"Reading files from: {file_path}")
    df = spark.read.csv(file_path, header=True, inferSchema=True)
    print(f"Read {df.count()} rows for state code: {state_code}")
    dfs.append(df)

print("Finished reading CSV files.")
print("Starting to clean column names...")

# Function to clean column names by replacing special characters with underscores
def clean_column_names(df):
    for col_name in df.columns:
        new_col_name = col_name.replace('-', '_').replace('/', '_').replace(' ', '_')
        df = df.withColumnRenamed(col_name, new_col_name)
    return df

# Clean column names for each DataFrame
dfs = [clean_column_names(df) for df in dfs]

print("Finished cleaning column names.")
print("Starting to ensure all DataFrames have the same columns...")

# Get the list of all columns
all_columns = set()
for df in dfs:
    all_columns.update(df.columns)

# Ensure all DataFrames have all columns
def add_missing_columns(df, all_columns):
    for column in all_columns:
        if column not in df.columns:
            df = df.withColumn(column, lit(None).cast("string"))
    return df

dfs = [add_missing_columns(df, all_columns) for df in dfs]

print("Finished ensuring all DataFrames have the same columns.")
print("Starting to select columns in the same order for consistency...")

# Select the columns in the same order for consistency
dfs = [df.select(*all_columns) for df in dfs]

print("Finished selecting columns in the same order.")
print("Starting to merge DataFrames...")

# Merge the DataFrames
merged_df = dfs[0]
for df in dfs[1:]:
    merged_df = merged_df.unionByName(df)

print("Finished merging DataFrames.")
print("Starting to save the merged DataFrame to a single CSV file...")

# Coalesce to a single partition and save the merged DataFrame to a single CSV file
merged_df.coalesce(1).write.csv("file:///home/talentum/myproject/dataSource/output/merged_final", header=True)

print("Finished saving the merged DataFrame.")
print("Stopping the Spark session...")

# Stop the Spark session
spark.stop()

print("Spark session stopped.")
# Out:
# Starting to read CSV files...
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/AP/*.csv
# Read 225716 rows for state code: AP
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/AR/*.csv
# Read 8131 rows for state code: AR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/AS/*.csv
# Read 73172 rows for state code: AS
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/BR/*.csv
# Read 636501 rows for state code: BR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/CG/*.csv
# Read 49048 rows for state code: CG
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/CH/*.csv
# Read 54786 rows for state code: CH
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/DL/*.csv
# Read 2118037 rows for state code: DL
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/GJ/*.csv
# Read 346017 rows for state code: GJ
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/HP/*.csv
# Read 8851 rows for state code: HP
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/HR/*.csv
# Read 1110835 rows for state code: HR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/JH/*.csv
# Read 52624 rows for state code: JH
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/JK/*.csv
# Read 16792 rows for state code: JK
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/KA/*.csv
# Read 1087206 rows for state code: KA
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/KL/*.csv
# Read 264335 rows for state code: KL
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/MH/*.csv
# Read 1264555 rows for state code: MH
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/ML/*.csv
# Read 30422 rows for state code: ML
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/MN/*.csv
# Read 14918 rows for state code: MN
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/MP/*.csv
# Read 572106 rows for state code: MP
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/MZ/*.csv
# Read 24991 rows for state code: MZ
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/NL/*.csv
# Read 21414 rows for state code: NL
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/OR/*.csv
# Read 102796 rows for state code: OR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/PB/*.csv
# Read 374848 rows for state code: PB
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/PY/*.csv
# Read 19109 rows for state code: PY
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/RJ/*.csv
# Read 485589 rows for state code: RJ
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/SK/*.csv
# Read 8048 rows for state code: SK
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/TG/*.csv
# Read 390250 rows for state code: TG
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/TN/*.csv
# Read 518525 rows for state code: TN
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/TR/*.csv
# Read 29013 rows for state code: TR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/UK/*.csv
# Read 10560 rows for state code: UK
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/UP/*.csv
# Read 1641091 rows for state code: UP
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/WB/*.csv
# Read 559152 rows for state code: WB
# Finished reading CSV files.
# Starting to clean column names...
# Finished cleaning column names.
# Starting to ensure all DataFrames have the same columns...
# Finished ensuring all DataFrames have the same columns.
# Starting to select columns in the same order for consistency...
# Finished selecting columns in the same order.
# Starting to merge DataFrames...
# Finished merging DataFrames.
# Starting to save the merged DataFrame to a single CSV file...
# Finished saving the merged DataFrame.
# Stopping the Spark session...
# Spark session stopped.

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, lit

# Initialize a Spark session
spark = SparkSession.builder.appName("CSV Merge").getOrCreate()

# List of state codes (assuming state_dict is defined elsewhere in your code)
state_codes = list(state_dict.values())

# Read the CSV files into a list of DataFrames
dfs = []
print("Starting to read CSV files...")
for state_code in state_codes:
    file_path = f"file:///home/talentum/myproject/dataSource/output/Cleaned/{state_code}/*.csv"
    print(f"Reading files from: {file_path}")
    df = spark.read.csv(file_path, header=True, inferSchema=True)
    print(f"Read {df.count()} rows for state code: {state_code}")
    dfs.append(df)

print("Finished reading CSV files.")
print("Starting to clean column names...")

# Function to clean column names by replacing special characters with underscores
def clean_column_names(df):
    for col_name in df.columns:
        new_col_name = col_name.replace('-', '_').replace('/', '_').replace(' ', '_')
        df = df.withColumnRenamed(col_name, new_col_name)
    return df

# Clean column names for each DataFrame
dfs = [clean_column_names(df) for df in dfs]

print("Finished cleaning column names.")
print("Starting to ensure all DataFrames have the same columns...")

# Get the list of all columns
all_columns = set()
for df in dfs:
    all_columns.update(df.columns)

# Ensure all DataFrames have all columns
def add_missing_columns(df, all_columns):
    for column in all_columns:
        if column not in df.columns:
            df = df.withColumn(column, lit(None).cast("string"))
    return df

dfs = [add_missing_columns(df, all_columns) for df in dfs]

print("Finished ensuring all DataFrames have the same columns.")
print("Starting to select columns in the same order for consistency...")

# Select the columns in the same order for consistency
dfs = [df.select(*all_columns) for df in dfs]

print("Finished selecting columns in the same order.")
print("Starting to merge DataFrames...")

# Merge the DataFrames
merged_df = dfs[0]
for df in dfs[1:]:
    merged_df = merged_df.unionByName(df)

print("Finished merging DataFrames.")
print("Starting to save the merged DataFrame to a Parquet file...")

# Coalesce to a single partition and save the merged DataFrame to a Parquet file
merged_df.coalesce(1).write.parquet("file:///home/talentum/myproject/dataSource/output/merged_final")

print("Finished saving the merged DataFrame as Parquet.")
print("Stopping the Spark session...")

# Stop the Spark session
spark.stop()

print("Spark session stopped.")
# Out:
# Starting to read CSV files...
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/AP/*.csv
# Read 225716 rows for state code: AP
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/AR/*.csv
# Read 8131 rows for state code: AR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/AS/*.csv
# Read 73172 rows for state code: AS
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/BR/*.csv
# Read 636501 rows for state code: BR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/CG/*.csv
# Read 49048 rows for state code: CG
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/CH/*.csv
# Read 54786 rows for state code: CH
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/DL/*.csv
# Read 2118037 rows for state code: DL
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/GJ/*.csv
# Read 346017 rows for state code: GJ
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/HP/*.csv
# Read 8851 rows for state code: HP
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/HR/*.csv
# Read 1110835 rows for state code: HR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/JH/*.csv
# Read 52624 rows for state code: JH
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/JK/*.csv
# Read 16792 rows for state code: JK
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/KA/*.csv
# Read 1087206 rows for state code: KA
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/KL/*.csv
# Read 264335 rows for state code: KL
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/MH/*.csv
# Read 1264555 rows for state code: MH
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/ML/*.csv
# Read 30422 rows for state code: ML
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/MN/*.csv
# Read 14918 rows for state code: MN
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/MP/*.csv
# Read 572106 rows for state code: MP
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/MZ/*.csv
# Read 24991 rows for state code: MZ
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/NL/*.csv
# Read 21414 rows for state code: NL
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/OR/*.csv
# Read 102796 rows for state code: OR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/PB/*.csv
# Read 374848 rows for state code: PB
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/PY/*.csv
# Read 19109 rows for state code: PY
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/RJ/*.csv
# Read 485589 rows for state code: RJ
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/SK/*.csv
# Read 8048 rows for state code: SK
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/TG/*.csv
# Read 390250 rows for state code: TG
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/TN/*.csv
# Read 518525 rows for state code: TN
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/TR/*.csv
# Read 29013 rows for state code: TR
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/UK/*.csv
# Read 10560 rows for state code: UK
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/UP/*.csv
# Read 1641091 rows for state code: UP
# Reading files from: file:///home/talentum/myproject/dataSource/output/Cleaned/WB/*.csv
# Read 559152 rows for state code: WB
# Finished reading CSV files.
# Starting to clean column names...
# Finished cleaning column names.
# Starting to ensure all DataFrames have the same columns...
# Finished ensuring all DataFrames have the same columns.
# Starting to select columns in the same order for consistency...
# Finished selecting columns in the same order.
# Starting to merge DataFrames...
# Finished merging DataFrames.
# Starting to save the merged DataFrame to a Parquet file...
# Finished saving the merged DataFrame as Parquet.
# Stopping the Spark session...
# Spark session stopped.
